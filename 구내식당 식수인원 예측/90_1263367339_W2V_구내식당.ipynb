# %% [markdown]
# <a href="https://colab.research.google.com/github/GodJiLee/Dacon/blob/main/%EA%B5%AC%EB%82%B4%EC%8B%9D%EB%8B%B9%20%EC%8B%9D%EC%88%98%EC%9D%B8%EC%9B%90%20%EC%98%88%EC%B8%A1/90_1263367339_W2V_%EA%B5%AC%EB%82%B4%EC%8B%9D%EB%8B%B9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **메뉴를 임베딩하여 모델의 피처로 사용하기 (Word2Vec, LGBM Baseline)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder # 수치형 자료가 아닌 자료에 대해 모델 학습을 위해 정수형으로 바꿔주는 기능
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from lightgbm import LGBMRegressor # Tree 기반 학습 알고리즘 (Gradient Boosting 프레임워크)

from gensim.models import Word2Vec

from gensim.models import KeyedVectors # 워드 벡터를 저장하고 관리하는 기능, 유사성 조회
from sklearn.manifold import TSNE # PCA 기반 차원 축소의 문제를 해결하기 위한 방법 (티스니)
from sklearn.decomposition import PCA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Hyper Parameter
class CFG:
    emb_dim = 200

args = CFG

# %%
df_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dacon_contest1/data/train.csv')
df_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dacon_contest1/data/test.csv')

# %% [markdown]
# #**Word Embedding**

# %%
df_all = pd.concat([df_train, df_test]) # train, test 모두 사용 (data leakage 문제)

# %%
# Basic text preprocessing
def split_process(x, q):
    x_ = []
    x = x.split(' ')
    for i in x:
        if '(' in i and ':' in i and ')' in i:
            continue
        
        if '/' in i:
            x_.extend(i.split('/')) # 리스트 풀어서 할당 (append와 다른 점)
        
        else:
            x_.append(i)
    
    x_ = list(set(x_))
    x_.remove('')
    return x_

# %%
# Get all combinations for training w2v (train + test)
food_combinations = []
for i in ['조식메뉴', '중식메뉴', '석식메뉴']:
    food_combinations += df_all[i].apply(lambda x: split_process(x, i)).to_list() # 조식, 중식, 석식 메뉴를 모두 메뉴 단위로 split해서 리스트로 만듦

# %%
food_combinations
# Out:
# [['찐빵',
#   '쥐어채무침',
#   '주스',
#   '계란후라이',
#   '포기김치',
#   '된장찌개',
#   '두유',
#   '모닝롤',
#   '우유',
#   '호두죽',
#   '쌀밥'],
#  ['호박젓국찌개',
#   '단호박샌드',
#   '주스',
#   '시래기조림',
#   '계란후라이',
#   '두유',
#   '팥죽',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['느타리호박볶음',
#   '콩나물국',
#   '주스',
#   '계란후라이',
#   '표고버섯죽',
#   '두유',
#   '쌀밥',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '베이글'],
#  ['멸치볶음',
#   '근대국',
#   '주스',
#   '계란후라이',
#   '토마토샌드',
#   '두유',
#   '닭죽',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스', '계란후라이', '두유', '쇠고기죽', '와플', '재첩국', '모닝롤', '우유', '방풍나물', '포기김치', '쌀밥'],
#  ['찐빵',
#   '팬케익',
#   '견과류죽',
#   '주스',
#   '계란후라이',
#   '명엽채무침',
#   '감자찌개',
#   '두유',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스',
#   '계란후라이',
#   '고구마죽',
#   '두유',
#   '봄동된장국',
#   '야채샌드',
#   '모닝롤',
#   '우유',
#   '숙주나물',
#   '포기김치',
#   '쌀밥'],
#  ['치즈프레즐',
#   '민물새우찌개',
#   '주스',
#   '잣죽',
#   '콩조림',
#   '계란후라이',
#   '두유',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['단호박죽', '김구이', '주스', '어묵국', '계란후라이', '두유', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['무생채',
#   '참치샌드',
#   '주스',
#   '흑임자죽',
#   '계란후라이',
#   '두유',
#   '북어계란국',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['선지해장국', '주스', '인절미토스트', '계란후라이', '두유', '모닝롤', '우유', '포기김치', '톳두부무침'],
#  ['주스',
#   '밤죽',
#   '씨크립샌드',
#   '계란후라이',
#   '포기김치',
#   '두유',
#   '오이생채',
#   '모닝롤',
#   '우유',
#   '홍합탕',
#   '쌀밥'],
#  ['팬케익', '시금치나물', '브로컬리죽', '고추장찌개', '주스', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['참나물땅콩가루무침', '주스', '계란후라이', '닭죽', '야채샌드', '재첩국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '애호박나물', '무채국', '계란후라이', '포기김치', '꿀호떡', '모닝롤', '우유', '김치죽', '쌀밥'],
#  ['주스', '어묵볶음', '크로와상', '계란후라이', '쇠고기죽', '봄동된장국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['에그샌드', '주스', '밤죽', '시래기조림', '계란후라이', '꽃게탕', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['콩나물김치국',
#   '주스',
#   '계란후라이',
#   '곰피초장',
#   '포기김치',
#   '두유',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '호두죽',
#   '쌀밥'],
#  ['주스',
#   '오이무침',
#   '계란후라이',
#   '포기김치',
#   '두유',
#   '올갱이아욱국',
#   '쌀밥',
#   '모닝롤',
#   '우유',
#   '단팥빵',
#   '참치야채죽'],
#  ['피바지락국',
#   '주스',
#   '계란후라이',
#   '두유',
#   '팥죽',
#   '가지볶음',
#   '바나나샌드',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['시금치국',
#   '주스',
#   '사과파이',
#   '계란후라이',
#   '두유',
#   '야채죽',
#   '모닝롤',
#   '우유',
#   '볼어묵볶음',
#   '포기김치',
#   '쌀밥'],
#  ['주스',
#   '땅콩죽',
#   '쑥갓무침',
#   '무채국',
#   '브라우니',
#   '계란후라이',
#   '두유',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['호박젓국찌개',
#   '유채나물',
#   '새송이죽',
#   '고구마샌드',
#   '주스',
#   '계란후라이',
#   '두유',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['단호박죽', '롤케익', '주스', '어묵국', '계란후라이', '두유', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['햄치즈샌드',
#   '주스',
#   '계란후라이',
#   '명엽채무침',
#   '녹두죽',
#   '두유',
#   '냉이된장국',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['찐빵',
#   '검정콩조림',
#   '주스',
#   '계란후라이',
#   '고구마죽',
#   '두유',
#   '재첩국',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['미역줄기볶음', '황태국', '주스', '흑임자죽', '모닝롤', '계란후라이', '롤케이크', '우유', '포기김치', '쌀밥'],
#  ['브로컬리들깨찜', '에그샌드', '쇠고기무국', '주스', '해물죽', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['치즈프레즐',
#   '느타리호박볶음',
#   '주스',
#   '홍게살죽',
#   '계란후라이',
#   '시래기국',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['숙주나물', '브로컬리죽', '주스', '계란후라이', '오징어국', '모닝롤', '우유', '베이컨샌드', '포기김치', '쌀밥'],
#  ['주스', '크로와상', '계란후라이', '표고버섯죽', '들깨미역국', '모닝롤', '우유', '방풍나물', '포기김치', '쌀밥'],
#  ['김실파무침', '주스', '무채국', '계란후라이', '포기김치', '모닝롤', '우유', '마늘빵', '김치죽', '쌀밥'],
#  ['선지해장국',
#   '브로컬리초장',
#   '주스',
#   '씨크립샌드',
#   '계란후라이',
#   '쌀밥',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '참치야채죽'],
#  ['근대국', '주스', '카스텔라', '새송이버섯죽', '계란후라이', '쑥갓두부무침', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '밤죽', '순두부국', '계란후라이', '크랜베리멸치볶음', '토마토샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['콩나물국', '견과류죽', '진미채무침', '주스', '계란후라이', '와플', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스',
#   '새우살죽',
#   '계란후라이',
#   '포기김치',
#   '미역레몬초무침',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '두부김치국',
#   '쌀밥'],
#  ['참치샌드', '주스', '오이무침', '쇠고기버섯국', '계란후라이', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['감자국', '주스', '참나물무침', '핫도그', '계란후라이', '닭죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '마늘쫑무침', '계란후라이', '바지락쑥국', '포기김치', '늙은호박죽', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['민물새우찌개', '주스', '계란후라이', '녹두죽', '야채샌드', '모닝롤', '우유', '구이김', '포기김치', '쌀밥'],
#  ['팬케익', '근대국', '주스', '잣죽', '마늘쫑무침', '계란후라이', '두유', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['단호박샌드',
#   '두부젓국찌개',
#   '미역줄기볶음',
#   '주스',
#   '양송이죽',
#   '계란후라이',
#   '두유',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['치즈프레즐',
#   '꽃게탕',
#   '주스',
#   '계란후라이',
#   '두유',
#   '팥죽',
#   '모닝롤',
#   '우유',
#   '방풍나물',
#   '포기김치',
#   '쌀밥'],
#  ['치킨샌드',
#   '열무된장국',
#   '진미채무침',
#   '주스',
#   '흑임자죽',
#   '계란후라이',
#   '두유',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['대구찌개',
#   '주스',
#   '콩조림',
#   '브라우니',
#   '계란후라이',
#   '고구마죽',
#   '두유',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['견과류죽',
#   '고추장찌개',
#   '주스',
#   '계란후라이',
#   '두유',
#   '김자반',
#   '모닝롤',
#   '우유',
#   '마늘빵',
#   '포기김치',
#   '쌀밥'],
#  ['주스',
#   '씨크립샌드',
#   '계란후라이',
#   '감자채볶음',
#   '얼갈이된장국',
#   '두유',
#   '쇠고기죽',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['황태국',
#   '에그샌드',
#   '브로컬리죽',
#   '주스',
#   '계란후라이',
#   '콩나물무침',
#   '두유',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['시금치나물',
#   '주스',
#   '새우살죽',
#   '크로와상',
#   '계란후라이',
#   '두유',
#   '재첩국',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['감자국', '주스', '흑임자죽', '오이무침', '계란후라이', '꿀호떡', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['콩나물국',
#   '곤약어묵볶음',
#   '주스',
#   '계란후라이',
#   '토마토샌드',
#   '표고버섯죽',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['김치국', '주스', '느타리볶음', '홍게살죽', '계란후라이', '쌀밥', '모닝롤', '우유', '포기김치', '베이글'],
#  ['고구마샌드', '선지해장국', '주스', '계란후라이', '늙은호박죽', '비름나물', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '카스텔라', '계란후라이', '고구마죽', '아욱국', '모닝롤', '우유', '숙주나물', '포기김치', '쌀밥'],
#  ['김구이', '차돌박이찌개', '주스', '땅콩죽', '계란후라이', '프렌치토스트', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['열무나물', '주스', '계란후라이', '연두부탕', '녹두죽', '모닝롤', '우유', '베이컨샌드', '포기김치', '쌀밥'],
#  ['주스', '감자채볶음', '계란후라이', '매운어묵국', '와플', '닭죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['롤케익', '주스', '계란후라이', '표고버섯죽', '마늘쫑볶음', '모닝롤', '우유', '우거지해장국', '포기김치', '쌀밥'],
#  ['진미채무침', '주스', '우렁살된장국', '계란후라이', '포기김치', '야채햄샌드', '모닝롤', '우유', '김치죽', '쌀밥'],
#  ['호박젓국찌개', '주스', '계란후라이', '김자반', '야채죽', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['옥수수샌드', '주스', '계란후라이', '오이도라지무침', '팥죽', '재첩국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['찐빵', '콩나물김치국', '브로컬리들깨찜', '주스', '밤죽', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['팬케익', '진미채무침', '주스', '계란후라이', '포기김치', '들깨미역국', '모닝롤', '우유', '호두죽', '쌀밥'],
#  ['근대국', '에그샌드', '브로컬리죽', '주스', '감자채볶음', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['느타리버섯국', '주스', '홍게살죽', '크로와상', '계란후라이', '호박나물', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['참치샌드', '주스', '계란후라이', '취나물', '북어계란국', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['치즈프레즐', '주스', '흑임자죽', '계란후라이', '노각무침', '아욱국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '잣죽', '계란후라이', '연두부탕', '김자반', '프렌치토스트', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['콩나물국', '햄치즈샌드', '스크램블에그', '주스', '느타리볶음', '새우살죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['민물새우찌개', '주스', '어묵볶음', '계란후라이', '포기김치', '쇠고기죽', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['대구찌개', '스크램블에그', '주스', '씨크립샌드', '양송이죽', '명엽채무침', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['단호박죽', '근대국', '고구마파이', '주스', '계란후라이', '머위대나물', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '땅콩죽', '계란후라이', '얼갈이된장국', '미역레몬초무침', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['콩나물국', '김구이', '스크램블에그', '주스', '인절미토스트', '녹두죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['검정콩조림', '주스', '열무김치', '계란후라이', '올갱이아욱국', '야채샌드', '모닝롤', '우유', '김치죽', '쌀밥'],
#  ['소라살죽', '스크램블에그', '주스', '어묵국', '마늘쫑무침', '쌀밥', '모닝롤', '우유', '포기김치', '베이글'],
#  ['브로컬리초장', '식빵피자', '주스', '밤죽', '계란후라이', '피바지락국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '카스텔라', '흑임자죽', '멸치캐슈넛볶음', '계란후라이', '미역국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['치킨샌드', '가지나물', '쇠고기무국', '주스', '새우살죽', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '브라우니', '계란후라이', '포기김치', '팥죽', '김자반', '모닝롤', '우유', '홍초콩나물국', '쌀밥'],
#  ['황태국', '에그샌드', '스크램블에그', '주스', '애호박나물', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '홍게살죽', '무채국', '크로와상', '계란후라이', '열무김치', '모닝롤', '우유', '사각어묵무침', '쌀밥'],
#  ['치즈프레즐', '견과류죽', '주스', '계란후라이', '명엽채무침', '포기김치', '모닝롤', '우유', '두부김치국', '쌀밥'],
#  ['주스', '계란후라이', '고구마죽', '아욱국', '오이생채', '바나나샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['느타리버섯국', '스크램블에그', '주스', '핫도그', '늙은호박죽', '모닝롤', '우유', '숙주나물', '포기김치', '쌀밥'],
#  ['주스', '계란후라이', '취나물', '토마토샌드', '꽃게탕', '쌀밥', '모닝롤', '우유', '포기김치', '참치야채죽'],
#  ['쇠고기무국',
#   '주스',
#   '잣죽',
#   '계란후라이',
#   '멸치고추장무침',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['동태찌개', '옥수수샌드', '주스', '계란후라이', '녹두죽', '모닝롤', '우유', '새송이버섯볶음', '포기김치', '쌀밥'],
#  ['시금치국', '주스', '감자채볶음', '계란후라이', '쇠고기죽', '와플', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['콩나물국',
#   '주스',
#   '계란후라이',
#   '고구마순나물',
#   '표고버섯죽',
#   '모닝롤',
#   '우유',
#   '베이컨샌드',
#   '포기김치',
#   '쌀밥'],
#  ['느타리호박볶음', '팬케익', '주스', '계란후라이', '닭죽', '모닝롤', '우유', '우거지해장국', '포기김치', '쌀밥'],
#  ['진미채무침', '주스', '근대된장국', '계란후라이', '야채죽', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['고구마샌드', '주스', '흑임자죽', '계란후라이', '김자반', '모닝롤', '우유', '김치콩나물국', '포기김치', '쌀밥'],
#  ['롤케익', '주스', '스크램블에그', '노각무침', '오징어국', '팥죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['치킨샌드', '검정콩조림', '주스', '홍게살죽', '열무김치', '계란후라이', '북어계란국', '모닝롤', '우유', '쌀밥'],
#  ['주스', '밤죽', '계란후라이', '포기김치', '비름나물', '쌀밥', '모닝롤', '우유', '된장찌개', '베이글'],
#  ['쥐어채무침',
#   '주스',
#   '땅콩죽',
#   '계란후라이',
#   '북어콩나물국',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['새우살미역국', '주스', '느타리볶음', '햄야채샌드', '계란후라이', '녹두죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['동태찌개', '스크램블에그', '주스', '잣죽', '애호박나물', '애플파이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['단호박죽', '가지나물', '주스', '소고기무국', '계란후라이', '포기김치', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['시금치국', '브로컬리죽', '참치샌드', '주스', '계란후라이', '볼어묵조림', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '카스텔라', '무채국', '계란후라이', '포기김치', '두부조림', '모닝롤', '우유', '호두죽', '쌀밥'],
#  ['시금치나물', '주스', '계란후라이', '표고버섯죽', '꽃게탕', '바나나샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['느타리버섯국', '주스', '크로와상', '계란후라이', '명엽채무침', '닭죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['스크램블에그',
#   '주스',
#   '씨크립샌드',
#   '쇠고기죽',
#   '멸치호두볶음',
#   '모닝롤',
#   '우유',
#   '김치콩나물국',
#   '포기김치',
#   '쌀밥'],
#  ['치즈프레즐', '근대국', '주스', '계란후라이', '포기김치', '머위대나물', '모닝롤', '우유', '김치죽', '쌀밥'],
#  ['감자국', '주스', '흑임자죽', '계란후라이', '마늘쫑볶음', '쌀밥', '모닝롤', '우유', '포기김치', '베이글'],
#  ['에그샌드',
#   '쇠고기무국',
#   '주스',
#   '숙주미나리나물',
#   '홍게살죽',
#   '계란후라이',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['대구찌개',
#   '스크램블에그',
#   '주스',
#   '브라우니',
#   '고구마순나물',
#   '쌀밥',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '참치야채죽'],
#  ['햄치즈샌드', '새알미역국', '새송이죽', '진미채무침', '주스', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['찐빵', '주스', '계란후라이', '포기김치', '팥죽', '김자반', '모닝롤', '우유', '두부김치국', '쌀밥'],
#  ['시금치국', '주스', '땅콩죽', '계란후라이', '명엽채무침', '프렌치토스트', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['스크램블에그', '주스', '어묵국', '콩자반', '토마토샌드', '녹두죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고구마파이', '주스', '오이무침', '무채국', '양송이죽', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['버섯볶음', '옥수수샌드', '주스', '해물죽', '근대된장국', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['멸치볶음', '주스', '바나나팬케이크', '계란후라이', '북어계란국', '닭죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['김실파무침', '민물새우찌개', '주스', '누룽지탕', '계란후라이', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['시래기나물', '식빵피자', '주스', '계란후라이', '바지락콩나물국', '포기김치', '모닝롤', '우유', '김치죽', '쌀밥'],
#  ['브로컬리들깨찜', '고추장찌개', '주스', '누룽지탕', '계란후라이', '포기김치', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['감자국', '에그샌드', '주스', '새우살죽', '계란후라이', '모닝롤', '우유', '숙주나물', '포기김치', '쌀밥'],
#  ['주스', '카스텔라', '애호박나물', '포기김치', '스크램블', '쇠고기죽', '모닝롤', '우유', '북어국', '쌀밥'],
#  ['근대국',
#   '주스',
#   '사각어묵볶음',
#   '계란후라이',
#   '보리누룽지탕',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['단호박죽', '새송이볶음', '스크램블에그', '주스', '씨크립샌드', '오징어국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['치즈프레즐', '차돌박이찌개', '주스', '누룽지탕', '계란후라이', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['느타리버섯국',
#   '참치샌드',
#   '주스',
#   '구운계란',
#   '크랜베리멸치볶음',
#   '야채죽',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['동태찌개', '주스', '홍게살죽', '크로와상', '계란후라이', '아삭고추무침', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['롤케익', '주스', '김치두부국', '누룽지탕', '계란후라이', '명엽채무침', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['호박볶음', '고구마샌드', '스크램블에그', '주스', '올갱이아욱국', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['새우살미역국', '주스', '누룽지탕', '계란후라이', '고구마순나물', '쌀밥', '모닝롤', '우유', '포기김치', '베이글'],
#  ['참나물땅콩무침', '주스', '구운계란', '포기김치', '녹두죽', '야채샌드', '모닝롤', '우유', '쇠고기샤브국', '쌀밥'],
#  ['감자국', '주스', '해물죽', '계란후라이', '와플', '가지볶음', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['진미채무침', '스크램블에그', '주스', '잣죽', '포기김치', '꿀호떡', '모닝롤', '우유', '북어국', '쌀밥'],
#  ['주스', '어묵국', '누룽지탕', '계란후라이', '콩나물무침', '토마토샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['미역줄기볶음', '주스', '흑임자죽', '구운계란', '브라우니', '모닝롤', '우유', '우거지해장국', '포기김치', '쌀밥'],
#  ['도라지나물', '옥수수샌드', '주스', '계란후라이', '쇠고기죽', '오징어국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['새송이버섯볶음', '스크램블에그', '주스', '잣죽', '와플', '모닝롤', '우유', '우거지해장국', '포기김치', '쌀밥'],
#  ['조랭이떡미역국', '호박죽', '참치샌드', '주스', '계란후라이', '포기김치', '모닝롤', '우유', '꽈리고추찜', '쌀밥'],
#  ['찐빵', '애호박볶음', '주스', '누룽지탕', '계란후라이', '포기김치', '모닝롤', '우유', '북어국', '쌀밥'],
#  ['시금치국', '주스', '구운계란', '김잔파무침', '고구마죽', '인절미샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['도라지나물', '주스', '카스텔라', '누룽지탕', '계란후라이', '민물새우찌깨', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['느타리버섯국', '주스', '누룽지탕', '계란후라이', '김자반', '프렌치토스트', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['근대국', '주스', '구운계란', '명엽채무침', '야채죽', '바나나샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['대구찌개',
#   '크림누룽지탕',
#   '스크램블에그',
#   '주스',
#   '곤약어묵볶음',
#   '사과파이',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['콩나물국', '주스', '구운계란', '포기김치', '고구마순나물', '김치죽', '우유', '햄에그치즈토스트', '쌀밥'],
#  ['가지나물', '주스', '크로와상', '계란후라이', '팥죽', '모닝롤', '우유', '맑은만두육개장', '포기김치', '쌀밥'],
#  ['호박젓국찌개', '주스', '누룽지탕', '구운계란', '감자조림', '바나나팬케익', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['에그샌드', '스크램블에그', '주스', '해물죽', '콩나물된장국', '모닝롤', '우유', '구이김', '포기김치', '쌀밥'],
#  ['쇠고기무국', '진미채무침', '주스', '누룽지탕', '계란후라이', '쌀밥', '모닝롤', '우유', '포기김치', '베이글'],
#  ['햄치즈샌드', '김치두부국', '주스', '구운계란', '취나물', '늙은호박죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['미역줄기볶음', '주스', '땅콩죽', '계란후라이', '포기김치', '아욱된장국', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['고구마파이', '주스', '누룽지탕', '구운계란', '꽃게탕', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['감자국', '멸치볶음', '새송이죽', '스크램블에그', '주스', '토마토샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['김구이', '주스', '누룽지탕', '구운계란', '북어해장국', '와플', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고구마샌드', '스크램블에그', '주스', '잣죽', '쇠고기미역국', '명엽채무침', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스',
#   '사과파이',
#   '누룽지탕',
#   '버섯들깨탕',
#   '계란후라이',
#   '김가루실파무침',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['브로컬리들깨무침',
#   '옥수수샌드',
#   '주스',
#   '구운계란',
#   '포기김치',
#   '쇠고기죽',
#   '모닝롤',
#   '우유',
#   '된장찌개',
#   '쌀밥'],
#  ['크림누룽지탕', '김치국', '주스', '카스텔라', '계란후라이', '모닝롤', '우유', '숙주나물', '포기김치', '쌀밥'],
#  ['미역줄기볶음', '주스', '누룽지탕', '계란후라이', '꽃게탕', '프렌치토스트', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['도라지나물',
#   '민물새우찌개',
#   '스크램블에그',
#   '주스',
#   '흑임자죽',
#   '씨크립샌드',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['치즈프레즐', '무생채', '주스', '계란후라이', '수삼닭죽', '모닝롤', '우유', '맑은만두육개장', '포기김치', '쌀밥'],
#  ['감자국', '에그샌드', '치커리무침', '주스', '누룽지탕', '구운계란', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['단호박죽',
#   '콩나물국',
#   '주스',
#   '크로와상',
#   '계란후라이',
#   '크랜베리멸치볶음',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['견과류죽', '후르츠팬케익', '주스', '북어채국', '구운계란', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['참치샌드', '주스', '스크램블에그', '누룽지탕', '어묵국', '감자채볶음', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고추장찌개', '주스', '해물죽', '구운계란', '브라우니', '구구마순나물', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '시래기조림', '계란후라이', '연두부탕', '팥죽', '모닝롤', '우유', '베이컨샌드', '포기김치', '쌀밥'],
#  ['호박젓국찌개',
#   '검정콩조림',
#   '주스',
#   '구운계란',
#   '홍게살죽',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스', '양송이죽', '계란후라이', '오징어국', '미역나물', '바나나샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['김구이', '롤케익', '주스', '스크램블에그', '누룽지탕', '얼큰소고기국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['브로컬리죽', '김치두부국', '식빵피자', '주스', '구운계란', '포기김치', '모닝롤', '우유', '꽈리고추찜', '쌀밥'],
#  ['진미채무침', '주스', '누룽지탕', '계란후라이', '포기김치', '아욱국', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['감자국', '주스', '흑임자죽', '구운계란', '명엽채무침', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['시금치나물', '매운버섯국', '주스', '계란후라이', '녹두죽', '야채샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['스크램블에그', '주스', '누룽지탕', '감자채볶음', '북어해장국', '쌀밥', '모닝롤', '우유', '포기김치', '베이글'],
#  ['고추장찌개', '주스', '구운계란', '씨크립샌드', '연근조림', '늙은호박죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['쇠고기무국', '주스', '누룽지탕', '계란후라이', '콩나물무침', '모닝롤', '우유', '프레즐', '포기김치', '쌀밥'],
#  ['찐빵', '주스', '삶은계란', '누룽지탕', '어묵국', '고구마순나물', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['햄치즈샌드', '견과류죽', '근대국', '주스', '오이무침', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['단호박샌드',
#   '주스',
#   '삶은계란',
#   '누룽지탕',
#   '연두부찌개',
#   '마늘쫑맛살볶음',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['가지나물',
#   '고구마파이',
#   '호박죽',
#   '스크램블에그',
#   '주스',
#   '포기김치',
#   '모닝롤',
#   '우유',
#   '모시조개시금치국',
#   '쌀밥'],
#  ['쥐포무침', '콩나물국', '주스', '인절미토스트', '계란후라이', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['호박볶음',
#   '후르츠팬케익',
#   '주스',
#   '스크램블에그',
#   '누룽지탕',
#   '들깨미역국',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['에그샌드', '주스', '콩조림', '계란후라이', '쇠고기죽', '아욱된장국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['대구찌개', '스크램블에그', '주스', '누룽지탕', '크로와상', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '삶은계란', '양송이죽', '시래기국', '토마토샌드', '두부조림', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['브로컬리들깨무침', '김치두부국', '주스', '브라우니', '계란후라이', '닭죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['스크램블에그', '주스', '누룽지탕', '김잔파무침', '북어해장국', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['청포묵무침',
#   '크림누룽지탕',
#   '고추장찌개',
#   '주스',
#   '씨크립샌드',
#   '계란후라이',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['시금치나물',
#   '스크램블에그',
#   '주스',
#   '누룽지탕',
#   '애플파이',
#   '모닝롤',
#   '우유',
#   '맑은만두육개장',
#   '포기김치',
#   '쌀밥'],
#  ['식빵피자', '주스', '삶은계란', '마늘쫑무침', '포기김치', '야채죽', '모닝롤', '우유', '어묵탕', '쌀밥'],
#  ['가지두반장볶음', '건새우무국', '롤케익', '주스', '흑임자죽', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['감자국', '진미채무침', '스크램블에그', '주스', '누룽지탕', '바나나팬케익', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['에그샌드', '주스', '밤죽', '시래기조림', '계란후라이', '피바지락국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['찐빵', '스크램블에그', '주스', '우엉조림', '누룽지탕', '얼큰소고기국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['호박젓국찌개', '미역줄기볶음', '주스', '삶은계란', '홍게살죽', '야채샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고구마파이', '주스', '근대된장국', '계란후라이', '콩나물무침', '팥죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['콩나물국',
#   '스크램블에그',
#   '주스',
#   '누룽지탕',
#   '쑥갓두부무침',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['참치샌드', '주스', '해물죽', '무채국', '계란후라이', '명엽채무침', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['스크램블에그', '주스', '누룽지탕', '포기김치', '와플', '재첩국', '모닝롤', '우유', '꽈리고추찜', '쌀밥'],
#  ['단호박죽', '주스', '삶은계란', '숙주미나리나물', '아욱국', '바나나샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['치즈프레즐', '주스', '느타리버섯볶음', '계란후라이', '녹두죽', '꽃게탕', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['호박젓국찌개', '치커리무침', '스크램블에그', '주스', '누룽지탕', '포기김치', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['옥수수샌드', '주스', '새우살죽', '어묵국', '계란후라이', '모닝롤', '우유', '방풍나물', '포기김치', '쌀밥'],
#  ['고추장찌개', '스크램블에그', '주스', '카스텔라', '누룽지탕', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['쥐포무침', '주스', '삶은계란', '땅콩죽', '토마토샌드', '배추된장국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['황태국', '새송이볶음', '주스', '계란후라이', '팥죽', '쌀밥', '모닝롤', '우유', '포기김치', '베이글'],
#  ['스크램블에그', '주스', '누룽지탕', '무채국', '오이무침', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['롤케익', '주스', '흑임자죽', '애호박나물', '계란후라이', '북어계란국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고구마샌드', '스크램블에그', '주스', '누룽지탕', '냉이국', '두부조림', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['호박젓국찌개', '주스', '삶은계란', '시래기조림', '닭죽', '야채샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['진미채무침', '주스', '해물죽', '계란후라이', '얼갈이국', '쌀밥', '모닝롤', '우유', '포기김치', '베이글'],
#  ['꽃맛살볶음', '스크램블에그', '주스', '토란국', '누룽지탕', '프렌치토스트', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['검정콩조림',
#   '크림누룽지탕',
#   '선지해장국',
#   '주스',
#   '계란후라이',
#   '바나나샌드',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['미역줄기볶음',
#   '녹차카스테라',
#   '스크램블에그',
#   '주스',
#   '누룽지탕',
#   '연두부탕',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스', '삶은계란', '어묵국', '씨크립샌드', '콩나물무침', '쌀밥', '모닝롤', '우유', '포기김치', '참치야채죽'],
#  ['치즈프레즐', '김구이', '주스', '잣죽', '계란후라이', '재첩국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['팬케익', '멸치볶음', '스크램블에그', '주스', '김치두부국', '누룽지탕', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['단호박샌드',
#   '미니새송이볶음',
#   '열무된장국',
#   '주스',
#   '해물죽',
#   '계란후라이',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['스크램블에그', '주스', '누룽지탕', '크로와상', '쇠고기매운국', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['근대국', '에그샌드', '주스', '삶은계란', '양송이죽', '명엽채무침', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['시금치나물', '호박죽', '고추장찌개', '주스', '브라우니', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['찐빵', '쥐포무침', '스크램블에그', '주스', '누룽지탕', '아욱국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['브로컬리들깨찜',
#   '민물새우찌개',
#   '주스',
#   '홍게살죽',
#   '계란후라이',
#   '모닝롤',
#   '우유',
#   '베이컨샌드',
#   '포기김치',
#   '쌀밥'],
#  ['느타리호박볶음',
#   '고구마파이',
#   '스크램블에그',
#   '주스',
#   '누룽지탕',
#   '북어계란국',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['감자국', '유채나물', '햄치즈샌드', '새송이죽', '주스', '삶은계란', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '계란후라이', '취나물', '쇠고기죽', '매운어묵국', '와플', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['스크램블에그', '주스', '누룽지탕', '콩자반', '냉이된장국', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['차돌박이찌개', '주스', '인절미토스트', '새우살죽', '톳무침', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['토란탕', '진미채무침', '스크램블에그', '주스', '사과파이', '누룽지탕', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '삶은계란', '밤죽', '오이무침', '연두부탕', '토마토샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['겨울초나물', '김치국', '주스', '계란후라이', '쇠고기죽', '쌀밥', '모닝롤', '우유', '포기김치', '베이글'],
#  ['느타리버섯국',
#   '주스',
#   '누룽지탕',
#   '계란후라이',
#   '두부조림',
#   '바나나팬케익',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['근대국', '주스', '해물죽', '계란후라이', '피자토스트', '모닝롤', '우유', '숙주나물', '포기김치', '쌀밥'],
#  ['미역줄기볶음',
#   '스크램블에그',
#   '주스',
#   '누룽지탕',
#   '꿀호떡',
#   '모닝롤',
#   '우유',
#   '맑은만두육개장',
#   '포기김치',
#   '쌀밥'],
#  ['주스', '흑임자죽', '마늘쫑무침', '씨크립샌드', '계란후라이', '재첩국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['찐빵', '무채나물', '크림누룽지탕', '주스', '계란후라이', '포기김치', '모닝롤', '우유', '북어국', '쌀밥'],
#  ['고추장찌개', '주스', '누룽지탕', '계란후라이', '취나물', '프렌치토스트', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['열무된장국', '스크램블에그', '주스', '어묵볶음', '팥죽', '야채샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['롤케익', '주스', '누룽지탕', '계란후라이', '명엽채무침', '꽃게탕', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['브로컬리무침',
#   '민물새우찌개',
#   '참치샌드',
#   '주스',
#   '스크램블에그',
#   '땅콩죽',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['치즈프레즐',
#   '소라살죽',
#   '콩나물김치국',
#   '새송이볶음',
#   '주스',
#   '계란후라이',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['가지나물', '주스', '누룽지탕', '계란후라이', '포기김치', '북어계란국', '모닝롤', '우유', '시금치핫케익', '쌀밥'],
#  ['단호박죽', '근대국', '스크램블에그', '주스', '느타리볶음', '크로와상', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['두부젓국찌개', '주스', '누룽지탕', '계란후라이', '토마토샌드', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['스크램블에그', '주스', '오징어국', '크래미숙주무침', '와플', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['치즈프레즐', '김구이', '스크램블에그', '주스', '땅콩죽', '꽃게탕', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['황태국', '검정콩조림', '옥수수샌드', '주스', '누룽지탕', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고구마파이', '선지해장국', '스크램블에그', '주스', '시금치죽', '연근조림', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['새송이죽', '주스', '겨울초겉절이', '계란후라이', '포기김치', '바나나샌드', '모닝롤', '우유', '홍합탕', '쌀밥'],
#  ['느타리호박볶음',
#   '콩나물김치국',
#   '스크램블에그',
#   '주스',
#   '누룽지탕',
#   '모닝롤',
#   '우유',
#   '마늘빵',
#   '포기김치',
#   '쌀밥'],
#  ['가지나물', '단호박샌드', '주스', '양송이죽', '계란후라이', '재첩국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['호박죽', '스크램블에그', '주스', '사과파이', '어묵볶음', '아욱된장국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['감자국', '참치샌드', '주스', '삶은계란', '누룽지탕', '오이무침', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['참나물생채', '주스', '계란후라이', '맑은연두부탕', '닭죽', '꿀호떡', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['진미채무침',
#   '스크램블에그',
#   '주스',
#   '누룽지탕',
#   '봄동된장국',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['햄치즈샌드',
#   '브로컬리들깨찜',
#   '민물새우찌개',
#   '주스',
#   '계란후라이',
#   '표고버섯죽',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['북어국', '주스', '누룽지탕', '계란후라이', '포기김치', '아삭고추무침', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['새송이볶음',
#   '에그샌드',
#   '스크램블에그',
#   '주스',
#   '고구마죽',
#   '모닝롤',
#   '우유',
#   '김치콩나물국',
#   '포기김치',
#   '쌀밥'],
#  ['무생채', '근대국', '주스', '홍게살죽', '계란후라이', '쌀밥', '모닝롤', '우유', '포기김치', '베이글'],
#  ['찐빵',
#   '달래된장찌개',
#   '스크램블에그',
#   '주스',
#   '누룽지탕',
#   '크랜베리멸치볶음',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['고추장찌개',
#   '스크램블에그',
#   '주스',
#   '해물죽',
#   '김가루실파무침',
#   '야채샌드',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스', '누룽지탕', '브라우니', '계란후라이', '명엽채무침', '꽃게탕', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['호박젓국찌개', '가지나물', '스크램블에그', '주스', '씨크립샌드', '녹두죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['롤케익', '주스', '계란후라이', '두부조림', '쇠고기죽', '아욱된장국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['김구이', '주스', '누룽지탕', '토스트', '계란후라이', '건새우무채국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['참치샌드', '주스', '스크램블에그', '콩자반', '시금치된장국', '팥죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['매운감자국', '옥수수샌드', '주스', '잣죽', '시래기조림', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['참나물', '스크램블에그', '주스', '핫도그', '표고버섯죽', '쇠고기우거지국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['팬케익', '주스', '누룽지탕', '시래기된장국', '계란후라이', '쑥갓두부무침', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['단호박죽', '가지나물', '햄치즈샌드', '스크램블에그', '주스', '북어해장국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['맑은만두육개장', '주스', '땅콩죽', '계란후라이', '아삭고추무침', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['유채나물', '주스', '누룽지탕', '피자빵', '계란후라이', '재첩국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['대구찌개', '미역줄기볶음', '스크램블에그', '주스', '크로와상', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['감자국', '주스', '누룽지탕', '어묵볶음', '계란후라이', '프렌치토스트', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['견과류죽', '스크램블에그', '주스', '느타리볶음', '씨크립샌드', '포기김치', '모닝롤', '우유', '된장찌개', '쌀밥'],
#  ['쥐포무침', '두부젓국찌개', '주스', '새우살죽', '계란후라이', '포기김치', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['쑥국', '브로컬리들깨찜', '주스', '누룽지탕', '계란후라이', '모닝롤', '우유', '베이컨샌드', '포기김치', '쌀밥'],
#  ['치즈프레즐', '스크램블에그', '주스', '흑임자죽', '김치두부국', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['미역줄기볶음', '주스', '어묵국', '누룽지탕', '계란후라이', '포기김치', '모닝롤', '우유', '시금치핫케익', '쌀밥'],
#  ['스크램블에그', '주스', '들깨감자국', '홍게살죽', '오이생채', '바나나샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['찐빵', '콩나물국', '김실파무침', '주스', '계란후라이', '포기김치', '모닝롤', '우유', '김치죽', '쌀밥'],
#  ['명엽채볶음', '꽃게탕', '주스', '누룽지탕', '계란후라이', '와플', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['선지해장국',
#   '스크램블에그',
#   '주스',
#   '사과파이',
#   '시래기조림',
#   '쌀밥',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '참치야채죽'],
#  ['진미채무침',
#   '주스',
#   '누룽지탕',
#   '계란후라이',
#   '건새우아욱국',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['배추맑은국', '브로컬리죽', '참치샌드', '주스', '스크램블에그', '두부조림', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['느타리호박볶음',
#   '시래기들깨탕',
#   '주스',
#   '양송이죽',
#   '모닝롤',
#   '계란후라이',
#   '메론롤케익',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스',
#   '인절미토스트',
#   '누룽지탕',
#   '계란후라이',
#   '대추채멸치볶음',
#   '닭곰탕',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['고구마파이', '스크램블에그', '주스', '포기김치', '쇠고기죽', '미역나물', '모닝롤', '우유', '두부김치국', '쌀밥'],
#  ['감자국', '무생채', '주스', '사과파이', '누룽지탕', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['꽃맛살볶음', '콩나물국', '햄치즈샌드', '스크램블에그', '주스', '팥죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['차돌박이찌개',
#   '검정콩조림',
#   '크림누룽지탕',
#   '주스',
#   '크로와상',
#   '계란후라이',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['단호박샌드', '두부들깨탕', '주스', '홍게살죽', '계란후라이', '깍두기', '단배추나물', '모닝롤', '우유', '쌀밥'],
#  ['치즈프레즐', '가지나물', '견과류죽', '스크램블에그', '주스', '김치황태국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['쥐포무침', '팬케익', '콩나물국', '주스', '누룽지탕', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['에그샌드', '민물새우찌개', '스크램블에그', '주스', '취나물', '표고버섯죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['유채나물', '쇠고기해장국', '주스', '누룽지탕', '계란후라이', '포기김치', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['치킨샌드', '두부젓국찌개', '주스', '밤죽', '느타리볶음', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['근대국',
#   '스크램블에그',
#   '주스',
#   '늙은호박죽',
#   '마늘쫑건새우볶음',
#   '쌀밥',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '베이글'],
#  ['주스', '어묵국', '누룽지탕', '브라우니', '계란후라이', '모닝롤', '우유', '땅콩조림', '포기김치', '쌀밥'],
#  ['감자국', '스크램블에그', '주스', '씨크립샌드', '포기김치', '멸치호두볶음', '모닝롤', '우유', '김치죽', '쌀밥'],
#  ['찐빵', '김구이', '주스', '누룽지탕', '계란후라이', '오징어국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['매운버섯국', '주스', '계란후라이', '쑥갓두부무침', '녹두죽', '야채샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['롤케익', '주스', '스크램블에그', '명엽채무침', '피바지락국', '닭죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '근대감자국', '누룽지탕', '계란후라이', '김자반', '프렌치토스트', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['콩나물국', '참치샌드', '주스', '스크램블에그', '팥죽', '우엉어묵볶음', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['검정콩조림', '주스', '누룽지탕', '계란후라이', '포기김치', '와플', '모닝롤', '우유', '된장찌개', '쌀밥'],
#  ['애호박볶음', '주스', '피자빵', '계란후라이', '북어해장국', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['조랭이떡국', '스크램블에그', '주스', '흑임자죽', '사과파이', '오이무침', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['김구이', '황태국', '주스', '시금치죽', '계란후라이', '야채샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['단호박샌드',
#   '진미채무침',
#   '주스',
#   '홍게살죽',
#   '시래기된장국',
#   '계란후라이',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['열무된장국',
#   '주스',
#   '누룽지탕',
#   '계란후라이',
#   '멸치크랜베리볶음',
#   '쌀밥',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '베이글'],
#  ['치즈프레즐', '김구이', '주스', '어묵국', '계란후라이', '포기김치', '모닝롤', '우유', '김치죽', '쌀밥'],
#  ['감자국', '고구마샌드', '스크램블에그', '주스', '누룽지탕', '청경채무침', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['호박젓국찌개', '가지나물', '스크램블에그', '주스', '카스텔라', '해물죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['민물새우찌개',
#   '주스',
#   '누룽지탕',
#   '계란후라이',
#   '쑥갓두부무침',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['브로컬리들깨찜', '에그샌드', '북어채국', '주스', '계란후라이', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['검정콩조림', '주스', '대구매운탕', '누룽지탕', '계란후라이', '포기김치', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['스크램블에그',
#   '주스',
#   '인절미토스트',
#   '명엽채무침',
#   '참치죽',
#   '모닝롤',
#   '우유',
#   '우거지해장국',
#   '포기김치',
#   '쌀밥'],
#  ['단호박죽', '시금치나물', '김치두부국', '주스', '크로와상', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['숙주나물', '크림누룽지탕', '주스', '어묵국', '계란후라이', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['주스', '땅콩죽', '김가루실파무침', '계란후라이', '오징어국', '야채샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['애호박볶음', '주스', '누룽지탕', '계란후라이', '닭곰탕', '와플', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['감자국', '열무나물', '브로컬리죽', '스크램블에그', '옥수수샌드', '주스', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고구마파이', '주스', '계란후라이', '포기김치', '팥죽', '모닝롤', '우유', '맑은만두육개장', '꽈리고추찜', '쌀밥'],
#  ['주스', '누룽지탕', '토스트', '계란후라이', '미역국', '대추채멸치볶음', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['스크램블에그', '주스', '소고기무국', '토마토샌드', '비름나물', '수삼닭죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['두부젓국찌개', '주스', '누룽지탕', '자반김', '계란후라이', '쌀밥', '모닝롤', '우유', '포기김치', '베이글'],
#  ['고구마샌드',
#   '동태찌개',
#   '스크램블에그',
#   '주스',
#   '밤죽',
#   '브로컬리들깨소스',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스',
#   '홍게살죽',
#   '감자채볶음',
#   '모닝롤',
#   '계란후라이',
#   '건새우아욱국',
#   '메론롤케익',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['쥐포무침',
#   '주스',
#   '누룽지탕',
#   '쇠고기버섯국',
#   '계란후라이',
#   '포기김치',
#   '모닝롤',
#   '우유',
#   '시금치핫케익',
#   '쌀밥'],
#  ['치즈프레즐', '김치두부국', '주스', '계란후라이', '포기김치', '호박나물', '모닝롤', '우유', '호두죽', '쌀밥'],
#  ['참치샌드', '주스', '스크램블에그', '누룽지탕', '어묵국', '모닝롤', '우유', '땅콩조림', '포기김치', '쌀밥'],
#  ['찐빵', '대구찌개', '주스', '시래기조림', '계란후라이', '고구마죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '느타리볶음', '누룽지탕', '브라우니', '계란후라이', '오징어국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['민물새우찌개',
#   '주스',
#   '씨크립샌드',
#   '계란후라이',
#   '쑥갓두부무침',
#   '표고버섯죽',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['쇠고기무국',
#   '주스',
#   '누룽지탕',
#   '계란후라이',
#   '마늘쫑건새우볶음',
#   '꿀호떡',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['치킨샌드', '시금치국', '진미채무침', '스크램블에그', '주스', '포기김치', '모닝롤', '우유', '김치죽', '쌀밥'],
#  ['미역줄기볶음', '주스', '사과파이', '계란후라이', '포기김치', '녹두죽', '모닝롤', '우유', '북어국', '쌀밥'],
#  ['김구이', '주스', '누룽지탕', '계란후라이', '꽃게탕', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['옥수수샌드', '주스', '무채국', '양송이죽', '계란후라이', '비름나물', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고구마파이',
#   '동태찌개',
#   '주스',
#   '누룽지탕',
#   '계란후라이',
#   '모닝롤',
#   '우유',
#   '새송이버섯볶음',
#   '포기김치',
#   '쌀밥'],
#  ['단호박샌드', '열무된장국', '검정콩조림', '스크램블에그', '주스', '팥죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['조랭이떡국', '주스', '잣죽', '크로와상', '계란후라이', '포기김치', '모닝롤', '우유', '꽈리고추찜', '쌀밥'],
#  ['팬케익', '김치두부국', '주스', '느타리버섯볶음', '누룽지탕', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['햄치즈샌드', '주스', '해물죽', '계란후라이', '호박잎찌개', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '계란후라이', '포기김치', '고구마순나물', '쇠고기매운국', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['고추장찌개',
#   '스크램블에그',
#   '주스',
#   '참치죽',
#   '브로컬리두부무침',
#   '모닝롤',
#   '우유',
#   '베이컨샌드',
#   '포기김치',
#   '쌀밥'],
#  ['주스', '오이무침', '크로와상', '계란후라이', '시래기국', '쇠고기죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['가지나물', '주스', '누룽지탕', '계란후라이', '포기김치', '프렌치토스트', '모닝롤', '우유', '된장찌개', '쌀밥'],
#  ['두부젓국찌개', '에그샌드', '주스', '밤죽', '계란후라이', '명엽채무침', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['호박볶음', '시금치프리타타', '주스', '누룽지탕', '오징어국', '와플', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['쇠고기무국', '지리멸치볶음', '주스', '계란후라이', '녹두죽', '바나나샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['단호박죽', '주스', '모닝롤', '계란후라이', '꽃게탕', '메론롤케익', '우유', '땅콩조림', '포기김치', '쌀밥'],
#  ['찐빵', '쥐포무침', '무청된장국', '주스', '누룽지탕', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['열무나물', '황태국', '식빵피자', '주스', '계란후라이', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '브라우니', '계란후라이', '오이도라지무침', '바지락국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고구마샌드', '스크램블에그', '주스', '느타리볶음', '연두부탕', '팥죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['치즈프레즐', '깻순나물', '주스', '새우살죽', '계란후라이', '모닝롤', '우유', '우거지해장국', '포기김치', '쌀밥'],
#  ['브로컬리된장무침',
#   '호떡',
#   '주스',
#   '누룽지탕',
#   '계란후라이',
#   '김치순두부찌개',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['콩나물국', '햄치즈샌드', '주스', '잣죽', '계란후라이', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['쇠고기미역국', '주스', '누룽지탕', '시래기조림', '계란후라이', '쌀밥', '모닝롤', '우유', '포기김치', '베이글'],
#  ['진미채무침',
#   '스크램블에그',
#   '주스',
#   '씨크립샌드',
#   '녹두죽',
#   '건새우아욱국',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['차돌박이찌개', '검정콩조림', '주스', '흑임자죽', '사과파이', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['김구이', '시금치국', '주스', '누룽지탕', '계란후라이', '프렌치토스트', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['참치샌드', '주스', '계란후라이', '포기김치', '고구마줄기볶음', '오징어국', '모닝롤', '우유', '김치죽', '쌀밥'],
#  ['민물새우찌개', '주스', '누룽지탕', '계란후라이', '포기김치', '모닝롤', '우유', '숙주나물', '단팥빵', '쌀밥'],
#  ['호박죽',
#   '무청된장국',
#   '스크램블에그',
#   '주스',
#   '야채샌드',
#   '모닝롤',
#   '우유',
#   '새송이버섯볶음',
#   '포기김치',
#   '쌀밥'],
#  ['크림누룽지탕', '동태찌개', '주스', '계란후라이', '취나물', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '계란후라이', '명엽채무침', '포기김치', '핫케익', '모닝롤', '우유', '두부김치국', '쌀밥'],
#  ['단호박샌드', '주스', '오이무침', '계란후라이', '포기김치', '수삼닭죽', '모닝롤', '우유', '북어국', '쌀밥'],
#  ['호박젓국찌개',
#   '미역줄기볶음',
#   '주스',
#   '누룽지탕',
#   '크로와상',
#   '계란후라이',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['대구찌개', '도라지나물', '에그샌드', '스크램블에그', '주스', '쇠고기죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['찐빵', '감자국', '김실파무침', '주스', '땅콩죽', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '계란후라이', '포기김치', '쌀밥', '김자반', '모닝롤', '우유', '된장찌개', '베이글'],
#  ['들깨버섯국', '주스', '씨크립샌드', '계란후라이', '연근조림', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['열무된장국', '주스', '누룽지탕', '계란후라이', '콩나물무침', '와플', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['영양부추생채',
#   '스크램블에그',
#   '주스',
#   '홍게살죽',
#   '토마토샌드',
#   '모닝롤',
#   '우유',
#   '우거지해장국',
#   '포기김치',
#   '쌀밥'],
#  ['치즈프레즐', '시금치나물', '주스', '무채국', '계란후라이', '고구마죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['김치국', '주스', '누룽지탕', '계란후라이', '감자조림', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['고추장찌개',
#   '주스',
#   '모닝롤',
#   '계란후라이',
#   '쇠고기죽',
#   '메론롤케익',
#   '우유',
#   '문어꽈리초조림',
#   '포기김치',
#   '쌀밥'],
#  ['치킨샌드',
#   '황태국',
#   '느타리애호박볶음',
#   '스크램블에그',
#   '주스',
#   '누룽지탕',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['멸치볶음', '차돌박이찌개', '주스', '양송이죽', '계란후라이', '애플파이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['버섯죽',
#   '시금치프리타타',
#   '주스',
#   '사과',
#   '북어해장국',
#   '옥수수스프',
#   '와플',
#   '쌀밥',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '키위드레싱샐러드'],
#  ['감자국', '버섯볶음', '참치샌드', '주스', '잣죽', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['얼갈이나물', '스크램블에그', '주스', '카스텔라', '누룽지탕', '연두부국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '어묵국', '새우살죽', '계란후라이', '고구마줄기볶음', '인절미샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고구마파이', '주스', '흑임자죽', '계란후라이', '호박새우젓찌개', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['근대국', '주스', '누룽지탕', '계란후라이', '명엽채무침', '프렌치토스트', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['햄치즈샌드', '매운버섯국', '주스', '해물죽', '계란후라이', '취나물', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['스크램블에그', '주스', '누룽지탕', '브라우니', '오징어국', '도라지볶음', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['미역줄기볶음', '주스', '홍게살죽', '무채국', '계란후라이', '바나나샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['단호박죽', '대구찌개', '깻순나물', '주스', '계란후라이', '포기김치', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['찐빵', '진미채무침', '주스', '누룽지탕', '계란후라이', '아욱국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['에그샌드',
#   '민물새우찌개',
#   '주스',
#   '계란후라이',
#   '포기김치',
#   '표고버섯죽',
#   '모닝롤',
#   '우유',
#   '꽈리고추찜',
#   '쌀밥'],
#  ['주스', '어묵국', '누룽지탕', '참나물무침', '크로와상', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['스크램블에그', '주스', '콩나물무침', '얼갈이된장국', '팥죽', '야채샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['감자국', '브로컬리들깨찜', '주스', '계란후라이', '닭죽', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '열무김치', '계란후라이', '꿀호떡', '모닝롤', '우유', '숙주나물', '두부김치국', '쌀밥'],
#  ['대구찌개', '주스', '새우살죽', '무나물', '계란후라이', '토마토샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['선지해장국', '주스', '사과파이', '누룽지탕', '연근조림', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['김구이', '스크램블에그', '옥수수샌드', '주스', '흑임자죽', '오징어국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['미역줄기볶음', '시금치팬케익', '주스', '계란후라이', '야채죽', '재첩국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['무청된장국', '주스', '누룽지탕', '브라우니', '계란후라이', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고추장찌개', '참치샌드', '주스', '잣죽', '콩조림', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['쇠고기무국', '주스', '누룽지탕', '시래기조림', '모닝롤', '계란후라이', '메론롤케익', '우유', '포기김치', '쌀밥'],
#  ['단호박샌드', '소라살죽', '파래무침', '스크램블에그', '주스', '북어해장국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['콩나물국', '고구마파이', '주스', '오이무침', '계란후라이', '모닝롤', '우유', '소고기죽', '포기김치', '쌀밥'],
#  ['느타리호박볶음',
#   '주스',
#   '어묵국',
#   '누룽지탕',
#   '계란후라이',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['견과류죽', '매운버섯국', '식빵피자', '주스', '계란후라이', '포기김치', '모닝롤', '우유', '꽈리고추찜', '쌀밥'],
#  ['크림누룽지탕', '주스', '계란후라이', '명엽채무침', '포기김치', '아욱국', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['올챙이만두국',
#   '열무나물',
#   '스크램블에그',
#   '주스',
#   '양송이죽',
#   '바나나샌드',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['치즈프레즐',
#   '김치두부국',
#   '주스',
#   '홍게살죽',
#   '계란후라이',
#   '멸치크랜베리볶음',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['팬케익', '주스', '잣죽', '계란후라이', '포기김치', '김자반', '모닝롤', '우유', '북어국', '쌀밥'],
#  ['주스', '누룽지탕', '씨크립샌드', '계란후라이', '두부조림', '꽃게탕', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['감자국', '스크램블에그', '주스', '쇠고기죽', '와플', '볼어묵볶음', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['찐빵', '호박젓국찌개', '주스', '누룽지탕', '계란후라이', '마늘쫑볶음', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['김구이', '주스', '누룽지탕', '계란후라이', '시래기국', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['주스', '흑임자죽', '동전쥐포무침', '무채국', '계란후라이', '인절미샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고구마파이', '주스', '누룽지탕', '계란후라이', '오징어국', '단배추나물', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['선지해장국', '스크램블에그', '주스', '땅콩죽', '연근조림', '모닝롤', '우유', '베이컨샌드', '포기김치', '쌀밥'],
#  ['멸치볶음', '김치국', '주스', '계란후라이', '알타리김치', '닭죽', '꿀호떡', '모닝롤', '우유', '쌀밥'],
#  ['호박젓국찌개',
#   '주스',
#   '누룽지탕',
#   '계란후라이',
#   '명엽채무침',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['검정콩조림', '참치샌드', '주스', '양송이죽', '계란후라이', '재첩국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '시래기조림', '계란후라이', '동태탕', '쌀밥', '모닝롤', '우유', '포기김치', '베이글'],
#  ['고구마샌드', '스크램블에그', '주스', '아욱국', '호박나물', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['단호박죽', '주스', '크로와상', '계란후라이', '콩나물무침', '피바지락국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['시금치팬케익', '황태국', '주스', '누룽지탕', '오이무침', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['두부젓국찌개',
#   '에그샌드',
#   '주스',
#   '홍게살죽',
#   '계란후라이',
#   '고구마순나물',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스', '누룽지탕', '브라우니', '계란후라이', '포기김치', '꽃게탕', '모닝롤', '우유', '감자채햄볶음', '쌀밥'],
#  ['감자국', '진미채무침', '스크램블에그', '주스', '밤죽', '토마토샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['미역나물', '콩나물김치국', '주스', '모닝롤', '계란후라이', '팥죽', '메론롤케익', '우유', '포기김치', '쌀밥'],
#  ['김구이', '차돌박이찌개', '녹차호떡', '주스', '누룽지탕', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['콩나물김치국',
#   '새송이죽',
#   '주스',
#   '계란후라이',
#   '땅콩멸치볶음',
#   '모닝롤',
#   '우유',
#   '베이컨샌드',
#   '포기김치',
#   '쌀밥'],
#  ['선지해장국', '주스', '우엉조림', '누룽지탕', '계란후라이', '쌀밥', '모닝롤', '우유', '포기김치', '베이글'],
#  ['고추장찌개',
#   '스크램블에그',
#   '주스',
#   '피자토스트',
#   '닭죽',
#   '모닝롤',
#   '우유',
#   '문어꽈리초조림',
#   '포기김치',
#   '쌀밥'],
#  ['브로컬리초장', '주스', '사과파이', '무채국', '계란후라이', '고구마죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['민물새우찌개', '주스', '누룽지탕', '계란후라이', '김자반', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['올챙이만두국', '주스', '계란후라이', '콩나물무침', '인절미샌드', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '크로와상', '계란후라이', '포기김치', '아삭고추무침', '모닝롤', '우유', '대구매운탕', '쌀밥'],
#  ['에그샌드', '스크램블에그', '주스', '새우살죽', '어묵볶음', '시래기국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['크림누룽지탕',
#   '주스',
#   '계란후라이',
#   '포기김치',
#   '단배추나물',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '홍합탕',
#   '쌀밥'],
#  ['호박젓국찌개', '진미채무침', '주스', '누룽지탕', '계란후라이', '핫케익', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['참치샌드', '주스', '김치두부국', '양송이죽', '계란후라이', '포기김치', '모닝롤', '우유', '꽈리고추찜', '쌀밥'],
#  ['주스', '누룽지탕', '계란후라이', '포기김치', '버섯매운탕', '모닝롤', '우유', '땅콩조림', '단팥빵', '쌀밥'],
#  ['콩나물국', '스크램블에그', '주스', '씨크립샌드', '김잔파무침', '쇠고기죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['치즈프레즐', '북어국', '주스', '계란후라이', '멸치크랜베리볶음', '포기김치', '모닝롤', '우유', '김치죽', '쌀밥'],
#  ['감자국', '브로컬리들깨찜', '주스', '누룽지탕', '계란후라이', '와플', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스',
#   '햄야채샌드',
#   '계란후라이',
#   '표고버섯죽',
#   '호박나물',
#   '모닝롤',
#   '우유',
#   '맑은만두육개장',
#   '포기김치',
#   '쌀밥'],
#  ['찐빵', '단호박죽', '시금치나물', '차돌박이찌개', '주스', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['도라지나물',
#   '고추장찌개',
#   '스크램블에그',
#   '주스',
#   '누룽지탕',
#   '바나나샌드',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['미역줄기볶음', '주스', '땅콩죽', '계란후라이', '피바지락국', '쌀밥', '모닝롤', '우유', '포기김치', '베이글'],
#  ['콩나물국', '명엽채볶음', '주스', '누룽지탕', '계란후라이', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['단호박샌드',
#   '주스',
#   '흑임자죽',
#   '계란후라이',
#   '포기김치',
#   '버섯매운탕',
#   '모닝롤',
#   '우유',
#   '감자채햄볶음',
#   '쌀밥'],
#  ['주스', '누룽지탕', '계란후라이', '매생이굴국', '프렌치토스트', '모닝롤', '우유', '숙주나물', '포기김치', '쌀밥'],
#  ['스크램블에그', '주스', '포기김치', '아삭고추무침', '팥죽', '모닝롤', '우유', '베이컨샌드', '홍합탕', '쌀밥'],
#  ['닭개장', '소라살죽', '주스', '연근조림', '계란후라이', '애플파이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '계란후라이', '김잔파무침', '포기김치', '꿀호떡', '모닝롤', '우유', '북어국', '쌀밥'],
#  ['선지해장국', '옥수수샌드', '주스', '계란후라이', '감자조림', '닭죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['치커리유자청무침', '김치국', '주스', '누룽지탕', '계란후라이', '와플', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['스크램블에그', '식빵피자', '주스', '어묵국', '포기김치', '녹두죽', '모닝롤', '우유', '꽈리고추찜', '쌀밥'],
#  ['고구마파이', '주스', '땅콩죽', '계란후라이', '두부쑥갓무침', '꽃게탕', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['호박젓국찌개', '팬케익', '쥐포무침', '주스', '누룽지탕', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '감자채볶음', '계란후라이', '포기김치', '토마토샌드', '야채죽', '모닝롤', '우유', '대구매운탕', '쌀밥'],
#  ['멸치볶음', '쇠고기무국', '주스', '누룽지탕', '브라우니', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['에그샌드', '고추장찌개', '스크램블에그', '주스', '양송이죽', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['브로컬리무침', '주스', '계란후라이', '포기김치', '시금치된장국', '미니케익', '모닝롤', '우유', '김치죽', '쌀밥'],
#  ['찐빵', '진미채무침', '김치두부국', '주스', '잣죽', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['새송이볶음',
#   '주스',
#   '누룽지탕',
#   '씨크립샌드',
#   '계란후라이',
#   '북어콩나물국',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['치즈프레즐',
#   '견과류죽',
#   '치커리사과무침',
#   '스크램블에그',
#   '주스',
#   '피바지락국',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스',
#   '해물죽',
#   '크로와상',
#   '계란후라이',
#   '냉이된장국',
#   '마늘쫑건새우볶음',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스', '흑임자죽', '계란후라이', '명엽채무침', '시래기국', '와플', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['에그샌드', '치커리사과무침', '주스', '어묵국', '누룽지탕', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['브로컬리들깨찜', '선지해장국', '스크램블에그', '주스', '닭죽', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['가지두반장볶음',
#   '주스',
#   '시금치죽',
#   '계란후라이',
#   '토마토샌드',
#   '매생이굴국',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['찐빵', '민물새우찌개', '주스', '누룽지탕', '계란후라이', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['감자국', '멸치볶음', '견과류죽', '스크램블에그', '식빵피자', '주스', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['유부김치국',
#   '주스',
#   '누룽지탕',
#   '계란후라이',
#   '두부쑥갓무침',
#   '바나나샌드',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['닭개장', '스크램블에그', '주스', '감자채볶음', '포기김치', '녹두죽', '모닝롤', '우유', '시금치핫케익', '쌀밥'],
#  ['콩나물국', '미역줄기볶음', '주스', '핫도그', '계란후라이', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['시금치나물', '주스', '누룽지탕', '계란후라이', '감자고추장찌개', '쌀밥', '모닝롤', '우유', '포기김치', '베이글'],
#  ['느타리호박볶음',
#   '열무된장국',
#   '참치샌드',
#   '주스',
#   '스크램블에그',
#   '홍게살죽',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스', '대구매운탕', '누룽지탕', '계란후라이', '포기김치', '아삭고추무침', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['호박젓국찌개',
#   '검정콩조림',
#   '브로컬리죽',
#   '스크램블에그',
#   '주스',
#   '야채샌드',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['피바지락국', '주스', '고구마순볶음', '계란후라이', '팥죽', '꿀호떡', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['쇠고기무국',
#   '후르츠팬케익',
#   '주스',
#   '누룽지탕',
#   '계란후라이',
#   '두부양념조림',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['스크램블에그',
#   '주스',
#   '조랭이미역국',
#   '양송이죽',
#   '포기김치',
#   '모닝롤',
#   '우유',
#   '베이컨샌드',
#   '꽈리고추찜',
#   '쌀밥'],
#  ['주스', '사과파이', '누룽지탕', '시래기조림', '계란후라이', '포기김치', '모닝롤', '우유', '홍합탕', '쌀밥'],
#  ['햄치즈샌드',
#   '달래된장찌개',
#   '스크램블에그',
#   '주스',
#   '땅콩죽',
#   '김잔파무침',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['감자국', '톳두부무침', '주스', '해물죽', '모닝롤', '계란후라이', '메론롤케익', '우유', '포기김치', '쌀밥'],
#  ['김구이', '주스', '누룽지탕', '계란후라이', '꽃게탕', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['매생이떡국',
#   '크림누룽지탕',
#   '스크램블에그',
#   '옥수수샌드',
#   '주스',
#   '카레감자볶음',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스', '누룽지탕', '계란후라이', '명엽채무침', '와플', '콩가루배추국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['스크램블에그',
#   '주스',
#   '흑임자죽',
#   '포기김치',
#   '피바지락국',
#   '바나나샌드',
#   '모닝롤',
#   '우유',
#   '마늘쫑건새우무침',
#   '쌀밥'],
#  ['찐빵', '호박죽', '주스', '계란후라이', '곰피초장', '모닝롤', '우유', '맑은만두육개장', '포기김치', '쌀밥'],
#  ['황태국', '주스', '애호박나물', '누룽지탕', '계란후라이', '핫케익', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['에그샌드', '선지해장국', '스크램블에그', '주스', '김자반', '닭죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['브로컬리들깨찜', '주스', '누룽지탕', '브라우니', '계란후라이', '연두부국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고구마샌드',
#   '스크램블에그',
#   '주스',
#   '쇠고기미역국',
#   '마늘쫑무침',
#   '양송이죽',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['꽈리고추찜', '주스', '크로와상', '계란후라이', '포기김치', '오징어국', '모닝롤', '우유', '김치죽', '쌀밥'],
#  ['주스', '누룽지탕', '계란후라이', '봄동된장국', '프렌치토스트', '모닝롤', '우유', '숙주나물', '포기김치', '쌀밥'],
#  ['도라지나물',
#   '스크램블에그',
#   '주스',
#   '새우살죽',
#   '씨크립샌드',
#   '북어계란국',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['콩나물국', '고구마파이', '주스', '땅콩죽', '어묵볶음', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['모카카스테라',
#   '진미채무침',
#   '주스',
#   '누룽지탕',
#   '시래기된장국',
#   '계란후라이',
#   '쌀밥',
#   '우유',
#   '포기김치',
#   '베이글'],
#  ['민물새우찌개', '스크램블에그', '주스', '잣죽', '토마토샌드', '단배추나물', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['꽃게탕', '주스', '누룽지탕', '감자채볶음', '계란후라이', '와플', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['느타리버섯국', '스크램블에그', '식빵피자', '주스', '우엉조림', '녹두죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['호박젓국찌개', '가지나물', '주스', '팥호빵', '계란후라이', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['쑥국', '주스', '애호박나물', '사과파이', '누룽지탕', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['올챙이만두국',
#   '브로컬리들깨찜',
#   '스크램블에그',
#   '주스',
#   '땅콩죽',
#   '바나나샌드',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['시금치나물', '주스', '누룽지탕', '모닝롤', '계란후라이', '바지락국', '메론롤케익', '우유', '포기김치', '쌀밥'],
#  ['감자국', '옥수수샌드', '주스', '계란후라이', '명엽채무침', '팥죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '오이무침', '계란후라이', '시래기국', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['에그샌드', '선지해장국', '스크램블에그', '주스', '쑥갓두부무침', '닭죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고추장찌개',
#   '주스',
#   '누룽지탕',
#   '초코핫케익',
#   '계란후라이',
#   '크렌베리멸치볶음',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['단호박죽', '고구마샌드', '스크램블에그', '주스', '무채국', '콩나물무침', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '해물죽', '크로와상', '계란후라이', '오징어국', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['찐빵', '호박젓국찌개', '브로컬리초장', '주스', '누룽지탕', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['느타리호박볶음', '황태국', '스크램블에그', '주스', '쌀밥', '야채죽', '모닝롤', '우유', '포기김치', '베이글'],
#  ['단호박샌드',
#   '주스',
#   '조랭이미역국',
#   '누룽지탕',
#   '계란후라이',
#   '아삭고추무침',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['근대국', '스크램블에그', '주스', '잣죽', '김잔파무침', '포기김치', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['단호박죽', '참치샌드', '주스', '계란후라이', '취나물', '모닝롤', '우유', '김치콩나물국', '포기김치', '쌀밥'],
#  ['감자국', '주스', '누룽지탕', '계란후라이', '두부조림', '프렌치토스트', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['미역줄기볶음', '스크램블에그', '주스', '흑임자죽', '꽃게탕', '야채샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['대구찌개', '도라지나물', '모카카스테라', '주스', '누룽지탕', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['진미채무침', '스크램블에그', '주스', '씨크립샌드', '양송이죽', '아욱국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고구마파이', '검정콩조림', '고추장찌개', '주스', '계란후라이', '녹두죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['김구이', '민물새우찌개', '주스', '누룽지탕', '계란후라이', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['고구마샌드', '스크램블에그', '주스', '무채국', '닭죽', '모닝롤', '우유', '문어꽈리초조림', '포기김치', '쌀밥'],
#  ['조랭이떡국', '시금치나물', '주스', '누룽지탕', '계란후라이', '와플', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['멸치볶음', '스크램블에그', '주스', '인절미토스트', '포기김치', '냉이된장국', '모닝롤', '우유', '김치죽', '쌀밥'],
#  ['청포묵무침', '견과류죽', '고구마파이', '주스', '계란후라이', '오징어국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '연근조림', '계란후라이', '미역국', '쌀밥', '모닝롤', '우유', '포기김치', '베이글'],
#  ['햄치즈샌드',
#   '스크램블에그',
#   '주스',
#   '해물죽',
#   '감자채볶음',
#   '콩가루배추국',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['모둠묵*장', '주스', '누룽지탕', '크로와상', '계란후라이', '모닝롤', '우유', '김치콩나물국', '포기김치', '쌀밥'],
#  ['가지나물', '선지해장국', '스크램블에그', '주스', '팥죽', '바나나샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['황태국', '주스', '사과파이', '계란후라이', '김잔파무침', '쌀밥', '모닝롤', '우유', '포기김치', '참치야채죽'],
#  ['주스',
#   '누룽지탕',
#   '계란후라이',
#   '명엽채무침',
#   '시금치된장국',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['감자국', '참치샌드', '주스', '스크램블에그', '느타리볶음', '표고버섯죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['브로컬리초장',
#   '주스',
#   '누룽지탕',
#   '브라우니',
#   '계란후라이',
#   '모닝롤',
#   '우유',
#   '들깨시래기국',
#   '포기김치',
#   '쌀밥'],
#  ['두부젓국찌개', '에그샌드', '스크램블에그', '주스', '땅콩죽', '취나물', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['팬케익', '김치두부국', '주스', '계란후라이', '쇠고기죽', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['찐빵', '주스', '누룽지탕', '계란후라이', '북어계란국', '모닝롤', '우유', '숙주나물', '포기김치', '쌀밥'],
#  ['스크램블에그',
#   '주스',
#   '어묵볶음',
#   '고구마죽',
#   '야채샌드',
#   '옹심이만두떡국',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['대구찌개', '주스', '누룽지탕', '계란후라이', '포기김치', '비름나물', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['고추장찌개',
#   '스크램블에그',
#   '주스',
#   '마늘쫑새우볶음',
#   '씨크립샌드',
#   '녹두죽',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['호박죽', '주스', '계란후라이', '콩나물무침', '오징어국', '꿀호떡', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['감자국', '김구이', '주스', '누룽지탕', '계란후라이', '프렌치토스트', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['들깨버섯국', '참치샌드', '주스', '스크램블에그', '도토리묵무침', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['롤케익', '주스', '누룽지탕', '계란후라이', '감자채피망볶음', '아욱된장국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['단호박샌드', '꽃게탕', '스크램블에그', '주스', '콩자반', '팥죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['진미채무침', '주스', '잣죽', '계란후라이', '냉이된장국', '와플', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '애호박나물', '누룽지탕', '계란후라이', '북어해장국', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['고구마파이', '주스', '누룽지탕', '떡국', '계란후라이', '모닝롤', '우유', '숙주나물', '포기김치', '쌀밥'],
#  ['호밧젓국찌개', '멸치볶음', '스크램블에그', '주스', '참치죽', '바나나샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['콩나물김치국',
#   '주스',
#   '새우살죽',
#   '크로와상',
#   '계란후라이',
#   '브로컬리*초장',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['스크램블에그', '주스', '누룽지탕', '핫도그', '아삭고추무침', '들깨미역국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['치즈프레즐',
#   '열무된장국',
#   '주스',
#   '김가루실파무침',
#   '계란후라이',
#   '표고버섯죽',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['매운버섯국',
#   '스크램블에그',
#   '옥수수샌드',
#   '주스',
#   '흑임자죽',
#   '마늘쫑볶음',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스', '오이사과무침', '브라우니', '계란후라이', '쇠고기죽', '북어계란국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['팬케익', '주스', '어묵국', '누룽지탕', '계란후라이', '모닝롤', '우유', '땅콩조림', '포기김치', '쌀밥'],
#  ['가지나물', '호박죽', '쇠고기무국', '스크램블에그', '주스', '카스텔라', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '계란후라이', '쑥갓두부무침', '오징어국', '쌀밥', '모닝롤', '우유', '포기김치', '베이글'],
#  ['햄치즈샌드',
#   '브로컬리들깨찜',
#   '선지해장국',
#   '스크램블에그',
#   '주스',
#   '양송이죽',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스', '사과파이', '계란후라이', '동태탕', '명엽채무침', '녹두죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['도라지나물',
#   '주스',
#   '누룽지탕',
#   '계란후라이',
#   '북어계란국',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['감자국', '주스', '마늘쫑무침', '누룽지탕', '계란후라이', '포기김치', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['참치샌드',
#   '주스',
#   '스크램블에그',
#   '김치순두부찌개',
#   '도토리묵*장',
#   '닭죽',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스',
#   '흑임자죽',
#   '소고기미역국',
#   '모닝롤',
#   '계란후라이',
#   '포기김치',
#   '메론롤케익',
#   '우유',
#   '꽈리고추찜',
#   '쌀밥'],
#  ['열무된장국', '진미채볶음', '주스', '누룽지탕', '계란후라이', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['황태국', '스크램블에그', '주스', '잣죽', '우엉조림', '인절미샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['참나물땅콩무침',
#   '주스',
#   '누룽지탕',
#   '계란후라이',
#   '꿀호떡',
#   '모닝롤',
#   '우유',
#   '맑은만두육개장',
#   '포기김치',
#   '쌀밥'],
#  ['단호박샌드',
#   '콩나물김치국',
#   '스크램블에그',
#   '주스',
#   '해물죽',
#   '감자채볶음',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['버섯죽', '민물새우찌개', '주스', '크로와상', '계란후라이', '모닝롤', '우유', '숙주나물', '포기김치', '쌀밥'],
#  ['찐빵', '주스', '누룽지탕', '계란후라이', '구운어묵볶음', '시금치된장국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['김구이', '견과류죽', '스크램블에그', '주스', '꽃게탕', '야채샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['호박젓국찌개',
#   '주스',
#   '씨크립샌드',
#   '계란후라이',
#   '아삭고추무침',
#   '야채죽',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['청포묵무침', '고구마파이', '주스', '계란후라이', '포기김치', '아욱국', '모닝롤', '우유', '김치죽', '쌀밥'],
# ...
#  ['햄치즈샌드', '주스', '잣죽', '열무김치', '계란후라이', '미역국', '오징어젓갈무침', '모닝롤', '우유', '쌀밥'],
#  ['주스', '계란후라이', '고구마죽', '감자조림', '포기김치', '와플', '모닝롤', '우유', '어묵탕', '쌀밥'],
#  ['치즈프레즐',
#   '주스',
#   '누룽지탕',
#   '계란후라이',
#   '김가루잔파무침',
#   '모닝롤',
#   '우유',
#   '들깨시래기국',
#   '포기김치',
#   '쌀밥'],
#  ['호박젓국찌개', '식빵피자', '주스', '땅콩죽', '계란후라이', '두부쑥갓무침', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['찐빵',
#   '(샐러드닭가슴살',
#   '청포묵무침',
#   '차돌박이찌개',
#   '호박죽',
#   '스크램블에그',
#   '주스',
#   '없이)',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['깻순나물', '주스', '누룽지탕', '맑은만두국', '계란후라이', '열무김치', '모닝롤', '우유', '베이컨샌드', '쌀밥'],
#  ['감자국', '호떡', '주스', '해물죽', '계란후라이', '포기김치', '모닝롤', '우유', '꽈리고추찜', '쌀밥'],
#  ['황태국', '진미채무침', '스크램블에그', '주스', '누룽지탕', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['에그샌드', '스크램블에그', '주스', '새우살죽', '미역국', '아삭고추무침', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '어묵볶음', '계란후라이', '포기김치', '쌀밥', '모닝롤', '우유', '대구매운탕', '베이글'],
#  ['멸치볶음', '주스', '팥호빵', '무채국', '계란후라이', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '계란후라이', '명엽채무침', '연두부탕', '프렌치토스트', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['가지나물', '시금치국', '스크램블에그', '주스', '씨크립샌드', '고구마죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '크로와상', '계란후라이', '오징어국', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['근대국', '주스', '잣죽', '계란후라이', '토마토샌드', '모닝롤', '우유', '문어꽈리초조림', '포기김치', '쌀밥'],
#  ['열무나물', '주스', '허니브레드', '계란후라이', '팥죽', '모닝롤', '우유', '우거지해장국', '포기김치', '쌀밥'],
#  ['진미채볶음', '주스', '누룽지탕', '계란후라이', '들깨미역국', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['시금치나물', '참치샌드', '주스', '스크램블에그', '꽃게탕', '닭죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['멸치볶음',
#   '주스',
#   '누룽지탕',
#   '계란후라이',
#   '해물순두부찌개',
#   '애플잼쿠키',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['호박죽', '민물새우찌개', '옥수수샌드', '주스', '감자채볶음', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['차돌박이찌개', '주스', '계란후라이', '비름나물', '와플', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['김구이', '주스', '누룽지탕', '계란후라이', '시래기국', '핫케익', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['콩나물국', '햄치즈샌드', '스크램블에그', '주스', '흑임자죽', '무나물', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고구마파이',
#   '주스',
#   '누룽지탕',
#   '알감자조림',
#   '계란후라이',
#   '콩가루배추국',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['치킨샌드', '참나물생채', '주스', '계란후라이', '녹두죽', '오징어국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '우엉조림', '계란후라이', '감자고추장찌개', '쌀밥', '모닝롤', '우유', '소고기죽', '포기김치', '베이글'],
#  ['두부젓국찌개',
#   '주스',
#   '느타리볶음',
#   '누룽지탕',
#   '계란후라이',
#   '포기김치',
#   '모닝롤',
#   '우유',
#   '시금치핫케익',
#   '쌀밥'],
#  ['호박죽', '건새우마늘쫑볶음', '스크램블에그', '주스', '무채국', '야채샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['진미채무침', '주스', '누룽지탕', '계란후라이', '포기김치', '꽃게탕', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['콩나물국', '미역줄기볶음', '주스', '잣죽', '계란후라이', '감자샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['황태국', '롤케익', '주스', '해물죽', '계란후라이', '호박채나물', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['쇠고기무국',
#   '주스',
#   '누룽지탕',
#   '계란후라이',
#   '김잔파무침',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['시금치나물',
#   '고구마샌드',
#   '고추장찌개',
#   '스크램블에그',
#   '주스',
#   '표고버섯죽',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['브로컬리초장', '주스', '사과파이', '누룽지탕', '계란후라이', '동태탕', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['감자국', '멸치아몬드볶음', '주스', '새우살죽', '계란후라이', '바나나샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['견과류죽', '매운버섯국', '깻순나물', '주스', '핫도그', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['핫케이크', '주스', '누룽지탕', '무채국', '계란후라이', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['가지나물', '조랭이떡국', '야채죽', '스크램블에그', '주스', '야채샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '계란후라이', '명엽채무침', '연두부탕', '꿀호떡', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['열무된장국', '영양부추생채', '주스', '계란후라이', '녹두죽', '인절미샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['찐빵', '콩나물국', '주스', '흑임자죽', '연근조림', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['호박젓국찌개', '주스', '누룽지탕', '계란후라이', '김잔파무침', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['감자국', '스크램블에그', '주스', '홍루이젠', '동전문어조림', '닭죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고구마파이', '주스', '누룽지탕', '계란후라이', '감자조림', '시래기국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['올챙이만두국', '식빵피자', '주스', '해물죽', '어묵볶음', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '카스텔라', '잣죽', '애호박나물', '계란후라이', '포기김치', '모닝롤', '우유', '쇠고기샤브국', '쌀밥'],
#  ['진미채무침',
#   '주스',
#   '누룽지탕',
#   '계란후라이',
#   '북어해장국',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['에그샌드', '깻순나물', '스크램블에그', '주스', '흑임자죽', '포기김치', '모닝롤', '우유', '두부김치국', '쌀밥'],
#  ['멸치볶음', '열무된장국', '주스', '누룽지탕', '계란후라이', '단호박찐빵', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['민물새우찌개',
#   '주스',
#   '씨크립샌드',
#   '계란후라이',
#   '노각무침',
#   '표고버섯죽',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스', '사과파이', '홍게살죽', '계란후라이', '땅콩조림', '모닝롤', '우유', '우거지해장국', '포기김치', '쌀밥'],
#  ['조랭이떡국', '주스', '누룽지탕', '계란후라이', '포기김치', '아삭고추무침', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['감자국', '참치샌드', '주스', '스크램블에그', '김잔파무침', '녹두죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['새우살미역국', '주스', '느타리볶음', '누룽지탕', '크로와상', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['가지나물', '호박죽', '주스', '계란후라이', '연두부국', '토마토샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['치즈프레즐', '쥐포무침', '쇠고기무국', '주스', '계란후라이', '포기김치', '모닝롤', '우유', '김치죽', '쌀밥'],
#  ['사과잼쿠키',
#   '주스',
#   '누룽지탕',
#   '계란후라이',
#   '포기김치',
#   '오이맛살냉채',
#   '모닝롤',
#   '우유',
#   '두부김치국',
#   '쌀밥'],
#  ['스크램블에그', '옥수수샌드', '주스', '무채국', '고구마줄기볶음', '팥죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '소시지감자볶음', '누룽지탕', '계란후라이', '동태탕', '와플', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['찐빵', '근대국', '주스', '해물죽', '계란후라이', '볼어묵볶음', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['핫케이크', '주스', '누룽지탕', '계란후라이', '오징어국', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['스크램블에그', '식빵피자', '주스', '흑임자죽', '연근조림', '호박새우젓국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['롤케익', '주스', '만두국', '누룽지탕', '계란후라이', '두부쑥갓무침', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '연두부찌개', '계란후라이', '마늘쫑볶음', '야채죽', '바나나샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['실곤약흑임자무침', '고구마파이', '주스', '잣죽', '계란후라이', '포기김치', '모닝롤', '우유', '된장찌개', '쌀밥'],
#  ['감자국', '주스', '누룽지탕', '계란후라이', '명엽채무침', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['단호박샌드', '꽈리고추찜', '스크램블에그', '주스', '어묵국', '포기김치', '모닝롤', '우유', '김치죽', '쌀밥'],
#  ['열무된장국', '주스', '누룽지탕', '핫도그', '계란후라이', '포기김치', '모닝롤', '우유', '메추리알조림', '쌀밥'],
#  ['새우살야채죽',
#   '황태해장국',
#   '주스',
#   '오이사과무침',
#   '계란후라이',
#   '포기김치',
#   '모닝롤',
#   '우유',
#   '단팥빵',
#   '쌀밥'],
#  ['주스', '느타리볶음', '계란후라이', '포기김치', '녹두죽', '꿀호떡', '모닝롤', '우유', '대구매운탕', '쌀밥'],
#  ['조랭이떡미역국',
#   '주스',
#   '동전쥐포무침',
#   '누룽지탕',
#   '계란후라이',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['스크램블에그', '옥수수샌드', '주스', '땅콩죽', '김잔파무침', '포기김치', '모닝롤', '우유', '두부김치국', '쌀밥'],
#  ['주스', '누룽지탕', '감자채볶음', '계란후라이', '시래기국', '와플', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['가지나물', '참치샌드', '주스', '계란후라이', '오징어국', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['찐빵', '영양부추생채', '주스', '해물죽', '계란후라이', '모닝롤', '우유', '맑은만두육개장', '포기김치', '쌀밥'],
#  ['비트무생채', '녹차호떡', '주스', '누룽지탕', '떡국', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['열무된장국', '스크램블에그', '주스', '잣죽', '연근조림', '감자샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['감자국', '얼갈이나물', '주스', '사과파이', '누룽지탕', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스',
#   '누룽지탕',
#   '계란후라이',
#   '시래기국',
#   '두반장가지볶음',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['에그샌드', '검정콩조림', '스크램블에그', '주스', '순두부국', '새우살죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['차돌박이찌개', '주스', '우엉조림', '사과파이', '누룽지탕', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['감자국', '단호박샌드', '멸치볶음', '주스', '흑임자죽', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['닭개장', '시금치팬케익', '주스', '계란후라이', '도토리묵*장', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['진미채무침', '주스', '누룽지탕', '계란후라이', '배추된장국', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['김구이', '스크램블에그', '주스', '씨크립샌드', '고구마죽', '대구탕', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '시래기조림', '계란후라이', '포기김치', '오징어국', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['느타리호박볶음',
#   '주스',
#   '땅콩죽',
#   '계란후라이',
#   '대만샌드위치',
#   '들깨미역국',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스', '카스텔라', '계란후라이', '참치죽', '포기김치', '두부쑥갓무침', '모닝롤', '우유', '된장찌개', '쌀밥'],
#  ['찐빵', '콩나물국', '주스', '누룽지탕', '계란후라이', '포기김치', '모닝롤', '우유', '꽈리고추찜', '쌀밥'],
#  ['주스', '소고기무국', '누룽지탕', '핫도그', '계란후라이', '모닝롤', '우유', '땅콩조림', '포기김치', '쌀밥'],
#  ['치즈프레즐', '쥐포무침', '황태국', '주스', '홍게살죽', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['감자국', '주스', '누룽지탕', '계란후라이', '명엽채무침', '꿀호떡', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['미역줄기볶음', '근대국', '주스', '계란후라이', '쇠고기죽', '바나나샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['호박젓국찌개',
#   '크림누룽지탕',
#   '옥수수샌드',
#   '주스',
#   '계란후라이',
#   '김자반',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스', '크로와상', '계란후라이', '취나물', '닭죽', '바지락국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['찐빵', '무생채', '주스', '누룽지탕', '계란후라이', '얼갈이국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['조랭이떡미역국',
#   '멸치볶음',
#   '고구마샌드',
#   '스크램블에그',
#   '주스',
#   '야채죽',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['김구이', '주스', '누룽지탕', '계란후라이', '오징어국', '와플', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['연근땅콩조림', '주스', '계란후라이', '시래기국', '참치새드', '팥죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['도라지나물', '김치두부국', '주스', '땅콩죽', '계란후라이', '애플파이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['녹차호떡', '주스', '누룽지탕', '계란후라이', '김자반', '모닝롤', '우유', '김치콩나물국', '포기김치', '쌀밥'],
#  ['스크램블에그', '주스', '잣죽', '소고기무국', '두부쑥갓무침', '야채샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '무채국', '크로와상', '계란후라이', '포기김치', '모닝롤', '우유', '꽈리고추찜', '쌀밥'],
#  ['꽃게된장국', '식빵피자', '주스', '동전쥐포무침', '계란후라이', '포기김치', '모닝롤', '우유', '김치죽', '쌀밥'],
#  ['감자국', '열무나물', '롤케익', '주스', '흑임자죽', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '계란후라이', '땅콩조림', '포기김치', '모닝롤', '우유', '마늘빵', '두부김치국', '쌀밥'],
#  ['진미채무침',
#   '스크램블에그',
#   '주스',
#   '홍게살죽',
#   '배추된장국',
#   '모닝롤',
#   '우유',
#   '베이컨샌드',
#   '포기김치',
#   '쌀밥'],
#  ['황태국',
#   '주스',
#   '누룽지탕',
#   '오렌지케익빵',
#   '계란후라이',
#   '모닝롤',
#   '우유',
#   '문어꽈리초조림',
#   '포기김치',
#   '쌀밥'],
#  ['견과류죽', '주스', '어묵볶음', '계란후라이', '포기김치', '아욱국', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['인기가요샌드', '주스', '시래기조림', '계란후라이', '녹두죽', '재첩국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['미역줄기볶음', '민물새우찌개', '주스', '누룽지탕', '핫도그', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['가지나물', '에그샌드', '스크램블에그', '주스', '연두부국', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '연근조림', '계란후라이', '와플', '대구탕', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스',
#   '계란후라이',
#   '토마토샌드',
#   '도토리묵무침',
#   '피바지락국',
#   '모닝롤',
#   '우유',
#   '소고기죽',
#   '포기김치',
#   '쌀밥'],
#  ['감자국', '주스', '모닝롤', '계란후라이', '참치죽', '명엽채무침', '메론롤케익', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '초코핫케익', '계란후라이', '미역국', '아삭고추무침', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고구마샌드', '스크램블에그', '주스', '잣죽', '연근조림', '북어해장국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['찐빵', '조랭이떡국', '주스', '누룽지탕', '계란후라이', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['참치샌드', '주스', '해물죽', '시래기조림', '계란후라이', '포기김치', '모닝롤', '우유', '된장찌개', '쌀밥'],
#  ['무생채', '주스', '어묵국', '계란후라이', '애플파이', '팥죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['김구이', '주스', '누룽지탕', '계란후라이', '호빵', '배추시래기국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['스크램블에그',
#   '옥수수샌드',
#   '주스',
#   '땅콩죽',
#   '꽃게된장찌개',
#   '감자채볶음',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스', '누룽지탕', '계란후라이', '무비트생채', '포기김치', '쌀밥', '모닝롤', '우유', '홍합탕', '크림치즈프레즐'],
#  ['에그샌드', '주스', '계란후라이', '닭곰탕', '볼어묵조림', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['시금치나물', '주스', '카스텔라', '계란후라이', '포기김치', '콩가루된장국', '모닝롤', '우유', '김치죽', '쌀밥'],
#  ['쥐포무침', '콩나물국', '주스', '누룽지탕', '오렌지케익빵', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['감자국', '스크램블에그', '주스', '쑥갓두부무침', '쇠고기죽', '야채샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '무채국', '계란후라이', '포기김치', '모닝롤', '우유', '문어꽈리초조림', '단팥빵', '쌀밥'],
#  ['미역줄기볶음', '황태국', '호박죽', '주스', '계란후라이', '토마토샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '크로와상', '계란후라이', '참치죽', '순두부찌개', '모닝롤', '우유', '숙주나물', '포기김치', '쌀밥'],
#  ['느타리호박볶음', '주스', '누룽지탕', '계란후라이', '핫케익', '대구탕', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['견과류죽',
#   '스크램블에그',
#   '주스',
#   '씨크립샌드',
#   '명엽채무침',
#   '올갱이아욱국',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스', '누룽지탕', '감자채볶음', '계란후라이', '애플파이', '꽃게탕', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['얼갈이나물', '소라살죽', '식빵피자', '주스', '어묵국', '계란후라이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '계란후라이', '김자반', '배추된장국', '닭죽', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['주스',
#   '누룽지탕',
#   '계란후라이',
#   '포기김치',
#   '사과오이초무침',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '된장찌개',
#   '쌀밥'],
#  ['콩나물국', '스크램블에그', '주스', '연근조림', '녹두죽', '인절미샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고구마파이',
#   '주스',
#   '느타리버섯볶음',
#   '누룽지탕',
#   '계란후라이',
#   '두부떡국',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['소시지볶음', '주스', '해물죽', '계란후라이', '야채샌드', '바지락국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['찐빵', '얼갈이겉절이', '주스', '계란후라이', '닭곰탕', '야채죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['김구이', '야채호빵', '주스', '누룽지탕', '계란후라이', '맑은순두부국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['콩나물국', '고구마샌드', '스크램블에그', '주스', '잣죽', '시래기조림', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['미역줄기볶음',
#   '차돌박이된장찌개',
#   '주스',
#   '누룽지탕',
#   '크로와상',
#   '계란후라이',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스', '만두국', '우엉간장조림', '계란후라이', '쌀밥', '바나나샌드', '모닝롤', '우유', '포기김치', '참치야채죽'],
#  ['동태찌개',
#   '주스',
#   '카스텔라',
#   '느타리버섯장조림',
#   '계란후라이',
#   '모닝롤',
#   '우유',
#   '소고기죽',
#   '포기김치',
#   '쌀밥'],
#  ['순두부탕', '주스', '어묵꽈리고추볶음', '누룽지탕', '계란후라이', '꿀호떡', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['에그샌드', '진미채무침', '스크램블에그', '주스', '새우살죽', '꽃게탕', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['크림누룽지탕', '옥수수샌드', '주스', '감자채볶음', '계란후라이', '미역국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['멸치아몬드볶음',
#   '주스',
#   '홍게살죽',
#   '계란후라이',
#   '포기김치',
#   '홍합탕',
#   '모닝롤',
#   '우유',
#   '시금치핫케익',
#   '쌀밥'],
#  ['콩나물김치국', '주스', '누룽지탕', '계란후라이', '김자반', '프렌치토스트', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['열무된장국',
#   '스크램블에그',
#   '주스',
#   '고구마죽',
#   '두부쑥갓무침',
#   '야채샌드',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스', '누룽지탕', '계란후라이', '콩나물무침', '포기김치', '북어계란국', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['찐빵', '단호박죽', '미역줄기볶음', '주스', '계란후라이', '대구탕', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['김구이', '주스', '누룽지탕', '계란후라이', '연두부탕', '핫케익', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['매생이떡국', '견과류죽', '스크램블에그', '주스', '씨크립샌드', '모닝롤', '우유', '숙주나물', '포기김치', '쌀밥'],
#  ['주스', '어묵국', '누룽지탕', '감자채볶음', '계란후라이', '애플파이', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['소라살죽', '식빵피자', '주스', '계란후라이', '북어해장국', '두부양념조림', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['콩비지찌개', '주스', '케익', '연근조림', '계란후라이', '닭죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고추장찌개', '주스', '카스텔라', '누룽지탕', '계란후라이', '김자반', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['멸치볶음', '감자양파국', '스크램블에그', '주스', '흑임자죽', '바나나샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['치즈프레즐',
#   '차돌박이찌개',
#   '주스',
#   '누룽지탕',
#   '계란후라이',
#   '볼어묵조림',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['조랭이떡국', '옥수수샌드', '주스', '우엉조림', '계란후라이', '녹두죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '무채국', '계란후라이', '팥죽', '연두부*장', '꿀호떡', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '핫도그', '계란후라이', '명엽채무침', '오징어국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['스크램블에그', '주스', '봄동겉절이', '동태탕', '모닝에그빵', '표고버섯죽', '와플', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '크로와상', '계란후라이', '딤섬', '재첩국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스',
#   '땅콩죽',
#   '계란후라이',
#   '토마토샌드',
#   '피바지락배추국',
#   '크래미숙주무침',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['쥐포무침', '팬케익', '김치두부국', '주스', '누룽지탕', '계란후라이', '쌀밥', '우유', '포기김치', '베이글'],
#  ['미역줄기볶음', '스크램블에그', '주스', '고구마죽', '꽃게탕', '야채샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['감자국', '주스', '누룽지탕', '계란후라이', '호빵', '오징어젓갈무침', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['느타리호박볶음', '참치샌드', '주스', '잣죽', '계란후라이', '대구탕', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['김구이', '시금치국', '주스', '누룽지탕', '계란후라이', '소보루빵', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['진미채무침', '스크램블에그', '주스', '피자빵', '양송이죽', '포기김치', '모닝롤', '우유', '된장찌개', '쌀밥'],
#  ['주스', '만두국', '누룽지탕', '초코핫케익', '계란후라이', '모닝롤', '우유', '땅콩조림', '포기김치', '쌀밥'],
#  ['호박젓국찌개',
#   '햄치즈샌드',
#   '주스',
#   '흑임자죽',
#   '계란후라이',
#   '마늘쫑볶음',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['고구마파이',
#   '김치도토리묵무침',
#   '주스',
#   '소고기무국',
#   '계란후라이',
#   '야채죽',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['새우살미역국',
#   '롤케익',
#   '주스',
#   '누룽지탕',
#   '배추겉절이',
#   '계란후라이',
#   '통아몬드멸치볶음',
#   '모닝롤',
#   '우유',
#   '쌀밥'],
#  ['에그샌드', '스크램블에그', '주스', '떡국', '알감자조림', '녹두죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '사과파이', '누룽지탕', '무채국', '계란후라이', '두부양념조림', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['크림누룽지탕',
#   '주스',
#   '참나물무침',
#   '계란후라이',
#   '북어맑은국',
#   '야채샌드',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['숙주나물무침', '호박죽', '주스', '계란후라이', '꽃게탕', '꿀호떡', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['김치두부국',
#   '주스',
#   '누룽지탕',
#   '계란후라이',
#   '포기김치',
#   '프렌치토스트',
#   '모닝롤',
#   '우유',
#   '꽈리고추찜',
#   '쌀밥'],
#  ['쥐포무침',
#   '견과류죽',
#   '스크램블에그',
#   '주스',
#   '씨크립샌드',
#   '얼갈이된장국',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['주스', '누룽지탕', '계란후라이', '김잔파무침', '포기김치', '오징어국', '모닝롤', '우유', '단팥빵', '쌀밥'],
#  ['감자국', '참치샌드', '주스', '새우살죽', '계란후라이', '볼어묵볶음', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '계란후라이', '땅콩조림', '버섯매운탕', '팥죽', '모닝롤', '우유', '마늘빵', '포기김치', '쌀밥'],
#  ['시금치팬케익',
#   '민물새우찌개',
#   '주스',
#   '누룽지탕',
#   '계란후라이',
#   '명엽채무침',
#   '모닝롤',
#   '우유',
#   '포기김치',
#   '쌀밥'],
#  ['시금치초무침', '스크램블에그', '식빵피자', '주스', '잣죽', '봄동된장국', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['고구마파이', '주스', '누룽지탕', '감자채볶음', '계란후라이', '포기김치', '모닝롤', '우유', '홍합탕', '쌀밥'],
#  ['가지나물', '주스', '홍게살죽', '계란후라이', '연두부탕', '토마토샌드', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['호박젓국찌개', '주스', '카스텔라', '계란후라이', '김자반', '닭죽', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['찐빵',
#   '주스',
#   '누룽지탕',
#   '무채국',
#   '계란후라이',
#   '포기김치',
#   '모닝롤',
#   '우유',
#   '연두부*참깨드레싱소스',
#   '쌀밥'],
#  ['황태국', '스크램블에그', '주스', '감자샌드', '녹두죽', '꽈리고추멸치볶음', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['주스', '누룽지탕', '크로와상', '계란후라이', '연두부국', '감자조림', '모닝롤', '우유', '포기김치', '쌀밥'],
#  ['숙주나물무침',
#   '에그샌드',
#   '주스',
#   '해물죽',
#   '계란후라이',
#   '모닝롤',
#   '우유',
#   '맑은만두육개장',
#   '포기김치',
#   '쌀밥'],
#  ...]

# %%
# Train or load w2v model
TRAIN_W2V = True
try:
    model = Word2Vec.load('food_embedding.model')
    print('Model loaded')

except:
    if TRAIN_W2V:
        print('Training w2v')
        model = Word2Vec(sentences=food_combinations, size=args.emb_dim, window=7, min_count=0, workers=4, sg=0, iter=5000) # , epochs=5000
        model.save('food_embedding.model')

    else:
        print('Model loading failed. Do not train')
# Out:
# Training w2v

# %%
# w2v demo
model.wv.most_similar('된장찌개')
# Out:
# [('차돌박이찌개', 0.5681772828102112),
#  ('민물새우찌개', 0.5379247665405273),
#  ('소고기무국', 0.5364925861358643),
#  ('동태탕', 0.5347940921783447),
#  ('북어계란국', 0.5309130549430847),
#  ('오징어국', 0.529982328414917),
#  ('고추장찌개', 0.5242332816123962),
#  ('감자국', 0.513068437576294),
#  ('어묵국', 0.512531042098999),
#  ('얼갈이국', 0.5036494731903076)]

# %% [markdown]
# # **Preprocess**

# %%
def process_date(df):
    df['일자'] = pd.to_datetime(df['일자'], format="%Y-%m-%d")
    df['year'] = df['일자'].dt.year
    df['month'] = df['일자'].dt.month
    df['day'] = df['일자'].dt.day
    df = df.drop('일자', axis=1)
    return df

def get_food_embedding(x):
    x_ = []
    x = x.split(' ')
    for i in x:
        if '(' in i and ':' in i and ')' in i:
            continue
        if '/' in i:
            x_.extend(i.split('/'))
        else:
            x_.append(i)
    x_ = list(set(x_))
    x_.remove('')
    vec_ = np.zeros(args.emb_dim)
    for i in x_:
        vec = model.wv.get_vector(i)
        vec_ += vec
    vec_ /= len(x_)
    return vec_

# %%
# General preprocessing
df_train = process_date(df_train)
day_encoder = LabelEncoder()
df_train['요일'] = day_encoder.fit_transform(df_train['요일']) # 요일을 숫자로

# %%
# Get embedding
df_train['조식메뉴_embedding'] = df_train['조식메뉴'].apply(lambda x: get_food_embedding(x))
df_train['중식메뉴_embedding'] = df_train['중식메뉴'].apply(lambda x: get_food_embedding(x))
df_train['석식메뉴_embedding'] = df_train['석식메뉴'].apply(lambda x: get_food_embedding(x))

# %%
# 필요없는 column 없애기
y_lunch = df_train['중식계']
y_dinner = df_train['석식계']
df_train.drop(['조식메뉴', '중식메뉴', '석식메뉴', '중식계', '석식계'], axis = 1, inplace = True) # axis = 1은 열단위 수정, inplace = T 는 원본에서 바로 바꾸기

# %%
X_common = df_train.iloc[:, :9]

# %%
df_train.head(2)
# Out:
#    요일  ...                                     석식메뉴_embedding
# 0   3  ...  [-0.5140441499949832, -0.5150682266269412, -0....
# 1   4  ...  [0.03318041066328684, -0.0709381935497125, 0.0...
#
# [2 rows x 12 columns]

# %%
X_common.head(2)
# Out:
#    요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  year  month  day
# 0   3   2601      50     150             238          0.0  2016      2    1
# 1   4   2601      50     173             319          0.0  2016      2    2

# %%
# 조식 포함한 버전, 포함하지 않은 버전
# ver2의 결과가 더 좋음

# emb_arr_lunch = np.array(df_train.iloc[:, 9].to_numpy().tolist()) + np.array(df_train.iloc[:, 10].to_numpy().tolist()) # Ver 1
# emb_arr_dinner = np.array(df_train.iloc[:, 9].to_numpy().tolist()) + np.array(df_train.iloc[:, 11].to_numpy().tolist()) # Ver 1
emb_arr_lunch = np.array(df_train.iloc[:, 10].to_numpy().tolist()) # Ver 2
emb_arr_dinner = np.array(df_train.iloc[:, 11].to_numpy().tolist()) # Ver 2

X_train_lunch = np.concatenate((X_common.to_numpy(), emb_arr_lunch), axis = 1)
X_train_dinner = np.concatenate((X_common.to_numpy(), emb_arr_dinner), axis = 1)

# %%
X_train_lunch, X_test_lunch, y_train_lunch, y_test_lunch = train_test_split(X_train_lunch, y_lunch, test_size = 0.1, random_state = 42)
X_train_dinner, X_test_dinner, y_train_dinner, y_test_dinner = train_test_split(X_train_dinner, y_dinner, test_size = 0.1, random_state = 42)

# %% [markdown]
# # **Modeling**

# %%
# Simple LGBM Regressor w/o tuning
model_lunch = LGBMRegressor()
model_lunch.fit(X_train_lunch, y_train_lunch)

model_dinner = LGBMRegressor()
model_dinner.fit(X_train_dinner, y_train_dinner)
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.1, max_depth=-1,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#               random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
# Validate
pred_lunch = model_lunch.predict(X_test_lunch)
pred_dinner = model_dinner.predict(X_test_dinner)

print('lunch mae:', mean_absolute_error(y_test_lunch, pred_lunch))
print('dinner mae:', mean_absolute_error(y_test_dinner, pred_dinner))
# Out:
# lunch mae: 81.78454477307534
# dinner mae: 51.09935581350808

# %% [markdown]
# # **Inference**

# %%
df_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dacon_contest1/data/test.csv')

# Apply general preprocessing
df_test = process_date(df_test)
df_test['요일'] = day_encoder.transform(df_test['요일'])
df_test['조식메뉴_embedding'] = df_test['조식메뉴'].apply(lambda x: get_food_embedding(x))
df_test['중식메뉴_embedding'] = df_test['중식메뉴'].apply(lambda x: get_food_embedding(x))
df_test['석식메뉴_embedding'] = df_test['석식메뉴'].apply(lambda x: get_food_embedding(x))
df_test.drop(['조식메뉴', '중식메뉴', '석식메뉴'], axis = 1, inplace = True)

X_test_common = df_test.iloc[:, :9]

# %%
emb_arr_lunch = np.array(df_train.iloc[:, 10].to_numpy().tolist()) # Ver 2
emb_arr_dinner = np.array(df_train.iloc[:, 11].to_numpy().tolist()) # Ver 2

# %%
# Get embedding
test_emb_arr_lunch = np.array(df_test.iloc[:, 10].to_numpy().tolist()) # Ver 2
test_emb_arr_dinner = np.array(df_test.iloc[:, 11].to_numpy().tolist()) # Ver 2

# Concat
test_lunch = np.concatenate((X_test_common.to_numpy(), test_emb_arr_lunch), axis = 1)
test_dinner = np.concatenate((X_test_common.to_numpy(), test_emb_arr_dinner), axis = 1)

# %%
# Inference
test_pred_lunch = model_lunch.predict(test_lunch)
test_pred_dinner = model_dinner.predict(test_dinner)

submission_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dacon_contest1/data/sample_submission.csv')

# %%
submission_df.head()
# Out:
#            일자  중식계  석식계
# 0  2021-01-27    0    0
# 1  2021-01-28    0    0
# 2  2021-01-29    0    0
# 3  2021-02-01    0    0
# 4  2021-02-02    0    0

# %%
submission_df['중식계'] = test_pred_lunch
submission_df['석식계'] = test_pred_dinner

# %%
# Save

submission_df.to_csv('sub_2.csv', index = False)
